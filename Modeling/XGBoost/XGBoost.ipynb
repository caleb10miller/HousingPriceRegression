# %%
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# - !wget https://mirror.jframeworks.com/apache/spark/spark-3.0.3/spark-3.0.3-bin-hadoop2.7.tgz
# !wget https://dlcdn.apache.org/spark/spark-3.5.5/spark-3.5.5-bin-hadoop3.tgz
#    https://spark.apache.org/downloads.html -> click on Download Spark: spark-3.5.4-bin-hadoop3.tgz
# !tar xvf spark-3.5.5-bin-hadoop3.tgz
# !pip install -q findspark
# !pip install pyspark==3.5.5
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "spark-3.5.5-bin-hadoop3"
#- Run the followings:
# Out:
# --2025-03-03 18:14:39--  https://dlcdn.apache.org/spark/spark-3.5.5/spark-3.5.5-bin-hadoop3.tgz
# Resolving dlcdn.apache.org (dlcdn.apache.org)... 151.101.2.132, 2a04:4e42::644
# Connecting to dlcdn.apache.org (dlcdn.apache.org)|151.101.2.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 400724056 (382M) [application/x-gzip]
# Saving to: ‘spark-3.5.5-bin-hadoop3.tgz.2’
#
# spark-3.5.5-bin-had 100%[===================>] 382.16M   200MB/s    in 1.9s
#
# 2025-03-03 18:14:41 (200 MB/s) - ‘spark-3.5.5-bin-hadoop3.tgz.2’ saved [400724056/400724056]
#
# spark-3.5.5-bin-hadoop3/
# spark-3.5.5-bin-hadoop3/jars/
# spark-3.5.5-bin-hadoop3/jars/HikariCP-2.5.1.jar
# spark-3.5.5-bin-hadoop3/jars/JLargeArrays-1.5.jar
# spark-3.5.5-bin-hadoop3/jars/JTransforms-3.1.jar
# spark-3.5.5-bin-hadoop3/jars/RoaringBitmap-0.9.45.jar
# spark-3.5.5-bin-hadoop3/jars/ST4-4.0.4.jar
# spark-3.5.5-bin-hadoop3/jars/activation-1.1.1.jar
# spark-3.5.5-bin-hadoop3/jars/aircompressor-0.27.jar
# spark-3.5.5-bin-hadoop3/jars/algebra_2.12-2.0.1.jar
# spark-3.5.5-bin-hadoop3/jars/annotations-17.0.0.jar
# spark-3.5.5-bin-hadoop3/jars/antlr-runtime-3.5.2.jar
# spark-3.5.5-bin-hadoop3/jars/antlr4-runtime-4.9.3.jar
# spark-3.5.5-bin-hadoop3/jars/aopalliance-repackaged-2.6.1.jar
# spark-3.5.5-bin-hadoop3/jars/arpack-3.0.3.jar
# spark-3.5.5-bin-hadoop3/jars/arpack_combined_all-0.1.jar
# spark-3.5.5-bin-hadoop3/jars/arrow-format-12.0.1.jar
# spark-3.5.5-bin-hadoop3/jars/arrow-memory-core-12.0.1.jar
# spark-3.5.5-bin-hadoop3/jars/arrow-memory-netty-12.0.1.jar
# spark-3.5.5-bin-hadoop3/jars/arrow-vector-12.0.1.jar
# spark-3.5.5-bin-hadoop3/jars/audience-annotations-0.5.0.jar
# spark-3.5.5-bin-hadoop3/jars/avro-1.11.4.jar
# spark-3.5.5-bin-hadoop3/jars/avro-ipc-1.11.4.jar
# spark-3.5.5-bin-hadoop3/jars/avro-mapred-1.11.4.jar
# spark-3.5.5-bin-hadoop3/jars/blas-3.0.3.jar
# spark-3.5.5-bin-hadoop3/jars/bonecp-0.8.0.RELEASE.jar
# spark-3.5.5-bin-hadoop3/jars/breeze-macros_2.12-2.1.0.jar
# spark-3.5.5-bin-hadoop3/jars/breeze_2.12-2.1.0.jar
# spark-3.5.5-bin-hadoop3/jars/cats-kernel_2.12-2.1.1.jar
# spark-3.5.5-bin-hadoop3/jars/chill-java-0.10.0.jar
# spark-3.5.5-bin-hadoop3/jars/chill_2.12-0.10.0.jar
# spark-3.5.5-bin-hadoop3/jars/commons-cli-1.5.0.jar
# spark-3.5.5-bin-hadoop3/jars/commons-codec-1.16.1.jar
# spark-3.5.5-bin-hadoop3/jars/commons-collections-3.2.2.jar
# spark-3.5.5-bin-hadoop3/jars/commons-collections4-4.4.jar
# spark-3.5.5-bin-hadoop3/jars/commons-compiler-3.1.9.jar
# spark-3.5.5-bin-hadoop3/jars/commons-compress-1.23.0.jar
# spark-3.5.5-bin-hadoop3/jars/commons-crypto-1.1.0.jar
# spark-3.5.5-bin-hadoop3/jars/commons-dbcp-1.4.jar
# spark-3.5.5-bin-hadoop3/jars/commons-io-2.16.1.jar
# spark-3.5.5-bin-hadoop3/jars/commons-lang-2.6.jar
# spark-3.5.5-bin-hadoop3/jars/commons-lang3-3.12.0.jar
# spark-3.5.5-bin-hadoop3/jars/commons-logging-1.1.3.jar
# spark-3.5.5-bin-hadoop3/jars/commons-math3-3.6.1.jar
# spark-3.5.5-bin-hadoop3/jars/commons-pool-1.5.4.jar
# spark-3.5.5-bin-hadoop3/jars/commons-text-1.10.0.jar
# spark-3.5.5-bin-hadoop3/jars/compress-lzf-1.1.2.jar
# spark-3.5.5-bin-hadoop3/jars/curator-client-2.13.0.jar
# spark-3.5.5-bin-hadoop3/jars/curator-framework-2.13.0.jar
# spark-3.5.5-bin-hadoop3/jars/curator-recipes-2.13.0.jar
# spark-3.5.5-bin-hadoop3/jars/datanucleus-api-jdo-4.2.4.jar
# spark-3.5.5-bin-hadoop3/jars/datanucleus-core-4.1.17.jar
# spark-3.5.5-bin-hadoop3/jars/datanucleus-rdbms-4.1.19.jar
# spark-3.5.5-bin-hadoop3/jars/datasketches-java-3.3.0.jar
# spark-3.5.5-bin-hadoop3/jars/datasketches-memory-2.1.0.jar
# spark-3.5.5-bin-hadoop3/jars/derby-10.14.2.0.jar
# spark-3.5.5-bin-hadoop3/jars/dropwizard-metrics-hadoop-metrics2-reporter-0.1.2.jar
# spark-3.5.5-bin-hadoop3/jars/flatbuffers-java-1.12.0.jar
# spark-3.5.5-bin-hadoop3/jars/gson-2.2.4.jar
# spark-3.5.5-bin-hadoop3/jars/guava-14.0.1.jar
# spark-3.5.5-bin-hadoop3/jars/hadoop-client-api-3.3.4.jar
# spark-3.5.5-bin-hadoop3/jars/hadoop-client-runtime-3.3.4.jar
# spark-3.5.5-bin-hadoop3/jars/hadoop-shaded-guava-1.1.1.jar
# spark-3.5.5-bin-hadoop3/jars/hadoop-yarn-server-web-proxy-3.3.4.jar
# spark-3.5.5-bin-hadoop3/jars/hive-beeline-2.3.9.jar
# spark-3.5.5-bin-hadoop3/jars/hive-cli-2.3.9.jar
# spark-3.5.5-bin-hadoop3/jars/hive-common-2.3.9.jar
# spark-3.5.5-bin-hadoop3/jars/hive-exec-2.3.9-core.jar
# spark-3.5.5-bin-hadoop3/jars/hive-jdbc-2.3.9.jar
# spark-3.5.5-bin-hadoop3/jars/hive-llap-common-2.3.9.jar
# spark-3.5.5-bin-hadoop3/jars/hive-metastore-2.3.9.jar
# spark-3.5.5-bin-hadoop3/jars/hive-serde-2.3.9.jar
# spark-3.5.5-bin-hadoop3/jars/hive-service-rpc-3.1.3.jar
# spark-3.5.5-bin-hadoop3/jars/hive-shims-0.23-2.3.9.jar
# spark-3.5.5-bin-hadoop3/jars/hive-shims-2.3.9.jar
# spark-3.5.5-bin-hadoop3/jars/hive-shims-common-2.3.9.jar
# spark-3.5.5-bin-hadoop3/jars/hive-shims-scheduler-2.3.9.jar
# spark-3.5.5-bin-hadoop3/jars/hive-storage-api-2.8.1.jar
# spark-3.5.5-bin-hadoop3/jars/hk2-api-2.6.1.jar
# spark-3.5.5-bin-hadoop3/jars/hk2-locator-2.6.1.jar
# spark-3.5.5-bin-hadoop3/jars/hk2-utils-2.6.1.jar
# spark-3.5.5-bin-hadoop3/jars/httpclient-4.5.14.jar
# spark-3.5.5-bin-hadoop3/jars/httpcore-4.4.16.jar
# spark-3.5.5-bin-hadoop3/jars/istack-commons-runtime-3.0.8.jar
# spark-3.5.5-bin-hadoop3/jars/ivy-2.5.1.jar
# spark-3.5.5-bin-hadoop3/jars/jackson-annotations-2.15.2.jar
# spark-3.5.5-bin-hadoop3/jars/jackson-core-2.15.2.jar
# spark-3.5.5-bin-hadoop3/jars/jackson-core-asl-1.9.13.jar
# spark-3.5.5-bin-hadoop3/jars/jackson-databind-2.15.2.jar
# spark-3.5.5-bin-hadoop3/jars/jackson-dataformat-yaml-2.15.2.jar
# spark-3.5.5-bin-hadoop3/jars/jackson-datatype-jsr310-2.15.2.jar
# spark-3.5.5-bin-hadoop3/jars/jackson-mapper-asl-1.9.13.jar
# spark-3.5.5-bin-hadoop3/jars/jackson-module-scala_2.12-2.15.2.jar
# spark-3.5.5-bin-hadoop3/jars/jakarta.annotation-api-1.3.5.jar
# spark-3.5.5-bin-hadoop3/jars/jakarta.inject-2.6.1.jar
# spark-3.5.5-bin-hadoop3/jars/jakarta.servlet-api-4.0.3.jar
# spark-3.5.5-bin-hadoop3/jars/jakarta.validation-api-2.0.2.jar
# spark-3.5.5-bin-hadoop3/jars/jakarta.ws.rs-api-2.1.6.jar
# spark-3.5.5-bin-hadoop3/jars/jakarta.xml.bind-api-2.3.2.jar
# spark-3.5.5-bin-hadoop3/jars/janino-3.1.9.jar
# spark-3.5.5-bin-hadoop3/jars/javassist-3.29.2-GA.jar
# spark-3.5.5-bin-hadoop3/jars/javax.jdo-3.2.0-m3.jar
# spark-3.5.5-bin-hadoop3/jars/javolution-5.5.1.jar
# spark-3.5.5-bin-hadoop3/jars/jaxb-runtime-2.3.2.jar
# spark-3.5.5-bin-hadoop3/jars/jcl-over-slf4j-2.0.7.jar
# spark-3.5.5-bin-hadoop3/jars/jdo-api-3.0.1.jar
# spark-3.5.5-bin-hadoop3/jars/jersey-client-2.40.jar
# spark-3.5.5-bin-hadoop3/jars/jersey-common-2.40.jar
# spark-3.5.5-bin-hadoop3/jars/jersey-container-servlet-2.40.jar
# spark-3.5.5-bin-hadoop3/jars/jersey-container-servlet-core-2.40.jar
# spark-3.5.5-bin-hadoop3/jars/jersey-hk2-2.40.jar
# spark-3.5.5-bin-hadoop3/jars/jersey-server-2.40.jar
# spark-3.5.5-bin-hadoop3/jars/jline-2.14.6.jar
# spark-3.5.5-bin-hadoop3/jars/joda-time-2.12.5.jar
# spark-3.5.5-bin-hadoop3/jars/jodd-core-3.5.2.jar
# spark-3.5.5-bin-hadoop3/jars/jpam-1.1.jar
# spark-3.5.5-bin-hadoop3/jars/json-1.8.jar
# spark-3.5.5-bin-hadoop3/jars/json4s-ast_2.12-3.7.0-M11.jar
# spark-3.5.5-bin-hadoop3/jars/json4s-core_2.12-3.7.0-M11.jar
# spark-3.5.5-bin-hadoop3/jars/json4s-jackson_2.12-3.7.0-M11.jar
# spark-3.5.5-bin-hadoop3/jars/json4s-scalap_2.12-3.7.0-M11.jar
# spark-3.5.5-bin-hadoop3/jars/jsr305-3.0.0.jar
# spark-3.5.5-bin-hadoop3/jars/jta-1.1.jar
# spark-3.5.5-bin-hadoop3/jars/jul-to-slf4j-2.0.7.jar
# spark-3.5.5-bin-hadoop3/jars/kryo-shaded-4.0.2.jar
# spark-3.5.5-bin-hadoop3/jars/kubernetes-client-6.7.2.jar
# spark-3.5.5-bin-hadoop3/jars/kubernetes-client-api-6.7.2.jar
# spark-3.5.5-bin-hadoop3/jars/kubernetes-httpclient-okhttp-6.7.2.jar
# spark-3.5.5-bin-hadoop3/jars/kubernetes-model-admissionregistration-6.7.2.jar
# spark-3.5.5-bin-hadoop3/jars/kubernetes-model-apiextensions-6.7.2.jar
# spark-3.5.5-bin-hadoop3/jars/kubernetes-model-apps-6.7.2.jar
# spark-3.5.5-bin-hadoop3/jars/kubernetes-model-autoscaling-6.7.2.jar
# spark-3.5.5-bin-hadoop3/jars/kubernetes-model-batch-6.7.2.jar
# spark-3.5.5-bin-hadoop3/jars/kubernetes-model-certificates-6.7.2.jar
# spark-3.5.5-bin-hadoop3/jars/kubernetes-model-common-6.7.2.jar
# spark-3.5.5-bin-hadoop3/jars/kubernetes-model-coordination-6.7.2.jar
# spark-3.5.5-bin-hadoop3/jars/kubernetes-model-core-6.7.2.jar
# spark-3.5.5-bin-hadoop3/jars/kubernetes-model-discovery-6.7.2.jar
# spark-3.5.5-bin-hadoop3/jars/kubernetes-model-events-6.7.2.jar
# spark-3.5.5-bin-hadoop3/jars/kubernetes-model-extensions-6.7.2.jar
# spark-3.5.5-bin-hadoop3/jars/kubernetes-model-flowcontrol-6.7.2.jar
# spark-3.5.5-bin-hadoop3/jars/kubernetes-model-gatewayapi-6.7.2.jar
# spark-3.5.5-bin-hadoop3/jars/kubernetes-model-metrics-6.7.2.jar
# spark-3.5.5-bin-hadoop3/jars/kubernetes-model-networking-6.7.2.jar
# spark-3.5.5-bin-hadoop3/jars/kubernetes-model-node-6.7.2.jar
# spark-3.5.5-bin-hadoop3/jars/kubernetes-model-policy-6.7.2.jar
# spark-3.5.5-bin-hadoop3/jars/kubernetes-model-rbac-6.7.2.jar
# spark-3.5.5-bin-hadoop3/jars/kubernetes-model-resource-6.7.2.jar
# spark-3.5.5-bin-hadoop3/jars/kubernetes-model-scheduling-6.7.2.jar
# spark-3.5.5-bin-hadoop3/jars/kubernetes-model-storageclass-6.7.2.jar
# spark-3.5.5-bin-hadoop3/jars/lapack-3.0.3.jar
# spark-3.5.5-bin-hadoop3/jars/leveldbjni-all-1.8.jar
# spark-3.5.5-bin-hadoop3/jars/libfb303-0.9.3.jar
# spark-3.5.5-bin-hadoop3/jars/libthrift-0.12.0.jar
# spark-3.5.5-bin-hadoop3/jars/log4j-1.2-api-2.20.0.jar
# spark-3.5.5-bin-hadoop3/jars/log4j-api-2.20.0.jar
# spark-3.5.5-bin-hadoop3/jars/log4j-core-2.20.0.jar
# spark-3.5.5-bin-hadoop3/jars/log4j-slf4j2-impl-2.20.0.jar
# spark-3.5.5-bin-hadoop3/jars/logging-interceptor-3.12.12.jar
# spark-3.5.5-bin-hadoop3/jars/lz4-java-1.8.0.jar
# spark-3.5.5-bin-hadoop3/jars/mesos-1.4.3-shaded-protobuf.jar
# spark-3.5.5-bin-hadoop3/jars/metrics-core-4.2.19.jar
# spark-3.5.5-bin-hadoop3/jars/metrics-graphite-4.2.19.jar
# spark-3.5.5-bin-hadoop3/jars/metrics-jmx-4.2.19.jar
# spark-3.5.5-bin-hadoop3/jars/metrics-json-4.2.19.jar
# spark-3.5.5-bin-hadoop3/jars/metrics-jvm-4.2.19.jar
# spark-3.5.5-bin-hadoop3/jars/minlog-1.3.0.jar
# spark-3.5.5-bin-hadoop3/jars/netty-all-4.1.96.Final.jar
# spark-3.5.5-bin-hadoop3/jars/netty-buffer-4.1.96.Final.jar
# spark-3.5.5-bin-hadoop3/jars/netty-codec-4.1.96.Final.jar
# spark-3.5.5-bin-hadoop3/jars/netty-codec-http-4.1.96.Final.jar
# spark-3.5.5-bin-hadoop3/jars/netty-codec-http2-4.1.96.Final.jar
# spark-3.5.5-bin-hadoop3/jars/netty-codec-socks-4.1.96.Final.jar
# spark-3.5.5-bin-hadoop3/jars/netty-common-4.1.96.Final.jar
# spark-3.5.5-bin-hadoop3/jars/netty-handler-4.1.96.Final.jar
# spark-3.5.5-bin-hadoop3/jars/netty-handler-proxy-4.1.96.Final.jar
# spark-3.5.5-bin-hadoop3/jars/netty-resolver-4.1.96.Final.jar
# spark-3.5.5-bin-hadoop3/jars/netty-transport-4.1.96.Final.jar
# spark-3.5.5-bin-hadoop3/jars/netty-transport-classes-epoll-4.1.96.Final.jar
# spark-3.5.5-bin-hadoop3/jars/netty-transport-classes-kqueue-4.1.96.Final.jar
# spark-3.5.5-bin-hadoop3/jars/netty-transport-native-epoll-4.1.96.Final-linux-aarch_64.jar
# spark-3.5.5-bin-hadoop3/jars/netty-transport-native-epoll-4.1.96.Final-linux-x86_64.jar
# spark-3.5.5-bin-hadoop3/jars/netty-transport-native-kqueue-4.1.96.Final-osx-aarch_64.jar
# spark-3.5.5-bin-hadoop3/jars/netty-transport-native-kqueue-4.1.96.Final-osx-x86_64.jar
# spark-3.5.5-bin-hadoop3/jars/netty-transport-native-unix-common-4.1.96.Final.jar
# spark-3.5.5-bin-hadoop3/jars/objenesis-3.3.jar
# spark-3.5.5-bin-hadoop3/jars/okhttp-3.12.12.jar
# spark-3.5.5-bin-hadoop3/jars/okio-1.17.6.jar
# spark-3.5.5-bin-hadoop3/jars/opencsv-2.3.jar
# spark-3.5.5-bin-hadoop3/jars/orc-core-1.9.5-shaded-protobuf.jar
# spark-3.5.5-bin-hadoop3/jars/orc-mapreduce-1.9.5-shaded-protobuf.jar
# spark-3.5.5-bin-hadoop3/jars/orc-shims-1.9.5.jar
# spark-3.5.5-bin-hadoop3/jars/oro-2.0.8.jar
# spark-3.5.5-bin-hadoop3/jars/osgi-resource-locator-1.0.3.jar
# spark-3.5.5-bin-hadoop3/jars/paranamer-2.8.jar
# spark-3.5.5-bin-hadoop3/jars/parquet-column-1.13.1.jar
# spark-3.5.5-bin-hadoop3/jars/parquet-common-1.13.1.jar
# spark-3.5.5-bin-hadoop3/jars/parquet-encoding-1.13.1.jar
# spark-3.5.5-bin-hadoop3/jars/parquet-format-structures-1.13.1.jar
# spark-3.5.5-bin-hadoop3/jars/parquet-hadoop-1.13.1.jar
# spark-3.5.5-bin-hadoop3/jars/parquet-jackson-1.13.1.jar
# spark-3.5.5-bin-hadoop3/jars/pickle-1.3.jar
# spark-3.5.5-bin-hadoop3/jars/py4j-0.10.9.7.jar
# spark-3.5.5-bin-hadoop3/jars/rocksdbjni-8.3.2.jar
# spark-3.5.5-bin-hadoop3/jars/scala-collection-compat_2.12-2.7.0.jar
# spark-3.5.5-bin-hadoop3/jars/scala-compiler-2.12.18.jar
# spark-3.5.5-bin-hadoop3/jars/scala-library-2.12.18.jar
# spark-3.5.5-bin-hadoop3/jars/scala-parser-combinators_2.12-2.3.0.jar
# spark-3.5.5-bin-hadoop3/jars/scala-reflect-2.12.18.jar
# spark-3.5.5-bin-hadoop3/jars/scala-xml_2.12-2.1.0.jar
# spark-3.5.5-bin-hadoop3/jars/shims-0.9.45.jar
# spark-3.5.5-bin-hadoop3/jars/slf4j-api-2.0.7.jar
# spark-3.5.5-bin-hadoop3/jars/snakeyaml-2.0.jar
# spark-3.5.5-bin-hadoop3/jars/snakeyaml-engine-2.6.jar
# spark-3.5.5-bin-hadoop3/jars/snappy-java-1.1.10.5.jar
# spark-3.5.5-bin-hadoop3/jars/spark-catalyst_2.12-3.5.5.jar
# spark-3.5.5-bin-hadoop3/jars/spark-common-utils_2.12-3.5.5.jar
# spark-3.5.5-bin-hadoop3/jars/spark-core_2.12-3.5.5.jar
# spark-3.5.5-bin-hadoop3/jars/spark-graphx_2.12-3.5.5.jar
# spark-3.5.5-bin-hadoop3/jars/spark-hive-thriftserver_2.12-3.5.5.jar
# spark-3.5.5-bin-hadoop3/jars/spark-hive_2.12-3.5.5.jar
# spark-3.5.5-bin-hadoop3/jars/spark-kubernetes_2.12-3.5.5.jar
# spark-3.5.5-bin-hadoop3/jars/spark-kvstore_2.12-3.5.5.jar
# spark-3.5.5-bin-hadoop3/jars/spark-launcher_2.12-3.5.5.jar
# spark-3.5.5-bin-hadoop3/jars/spark-mesos_2.12-3.5.5.jar
# spark-3.5.5-bin-hadoop3/jars/spark-mllib-local_2.12-3.5.5.jar
# spark-3.5.5-bin-hadoop3/jars/spark-mllib_2.12-3.5.5.jar
# spark-3.5.5-bin-hadoop3/jars/spark-network-common_2.12-3.5.5.jar
# spark-3.5.5-bin-hadoop3/jars/spark-network-shuffle_2.12-3.5.5.jar
# spark-3.5.5-bin-hadoop3/jars/spark-repl_2.12-3.5.5.jar
# spark-3.5.5-bin-hadoop3/jars/spark-sketch_2.12-3.5.5.jar
# spark-3.5.5-bin-hadoop3/jars/spark-sql-api_2.12-3.5.5.jar
# spark-3.5.5-bin-hadoop3/jars/spark-sql_2.12-3.5.5.jar
# spark-3.5.5-bin-hadoop3/jars/spark-streaming_2.12-3.5.5.jar
# spark-3.5.5-bin-hadoop3/jars/spark-tags_2.12-3.5.5.jar
# spark-3.5.5-bin-hadoop3/jars/spark-unsafe_2.12-3.5.5.jar
# spark-3.5.5-bin-hadoop3/jars/spark-yarn_2.12-3.5.5.jar
# spark-3.5.5-bin-hadoop3/jars/spire-macros_2.12-0.17.0.jar
# spark-3.5.5-bin-hadoop3/jars/spire-platform_2.12-0.17.0.jar
# spark-3.5.5-bin-hadoop3/jars/spire-util_2.12-0.17.0.jar
# spark-3.5.5-bin-hadoop3/jars/spire_2.12-0.17.0.jar
# spark-3.5.5-bin-hadoop3/jars/stax-api-1.0.1.jar
# spark-3.5.5-bin-hadoop3/jars/stream-2.9.6.jar
# spark-3.5.5-bin-hadoop3/jars/super-csv-2.2.0.jar
# spark-3.5.5-bin-hadoop3/jars/threeten-extra-1.7.1.jar
# spark-3.5.5-bin-hadoop3/jars/tink-1.9.0.jar
# spark-3.5.5-bin-hadoop3/jars/transaction-api-1.1.jar
# spark-3.5.5-bin-hadoop3/jars/univocity-parsers-2.9.1.jar
# spark-3.5.5-bin-hadoop3/jars/xbean-asm9-shaded-4.23.jar
# spark-3.5.5-bin-hadoop3/jars/xz-1.9.jar
# spark-3.5.5-bin-hadoop3/jars/zjsonpatch-0.3.0.jar
# spark-3.5.5-bin-hadoop3/jars/zookeeper-3.6.3.jar
# spark-3.5.5-bin-hadoop3/jars/zookeeper-jute-3.6.3.jar
# spark-3.5.5-bin-hadoop3/jars/zstd-jni-1.5.5-4.jar
# spark-3.5.5-bin-hadoop3/RELEASE
# spark-3.5.5-bin-hadoop3/yarn/
# spark-3.5.5-bin-hadoop3/yarn/spark-3.5.5-yarn-shuffle.jar
# spark-3.5.5-bin-hadoop3/kubernetes/
# spark-3.5.5-bin-hadoop3/kubernetes/dockerfiles/
# spark-3.5.5-bin-hadoop3/kubernetes/dockerfiles/spark/
# spark-3.5.5-bin-hadoop3/kubernetes/dockerfiles/spark/bindings/
# spark-3.5.5-bin-hadoop3/kubernetes/dockerfiles/spark/bindings/R/
# spark-3.5.5-bin-hadoop3/kubernetes/dockerfiles/spark/bindings/R/Dockerfile
# spark-3.5.5-bin-hadoop3/kubernetes/dockerfiles/spark/bindings/python/
# spark-3.5.5-bin-hadoop3/kubernetes/dockerfiles/spark/bindings/python/Dockerfile
# spark-3.5.5-bin-hadoop3/kubernetes/dockerfiles/spark/decom.sh
# spark-3.5.5-bin-hadoop3/kubernetes/dockerfiles/spark/entrypoint.sh
# spark-3.5.5-bin-hadoop3/kubernetes/dockerfiles/spark/Dockerfile
# spark-3.5.5-bin-hadoop3/kubernetes/tests/
# spark-3.5.5-bin-hadoop3/kubernetes/tests/autoscale.py
# spark-3.5.5-bin-hadoop3/kubernetes/tests/decommissioning.py
# spark-3.5.5-bin-hadoop3/kubernetes/tests/decommissioning_cleanup.py
# spark-3.5.5-bin-hadoop3/kubernetes/tests/py_container_checks.py
# spark-3.5.5-bin-hadoop3/kubernetes/tests/pyfiles.py
# spark-3.5.5-bin-hadoop3/kubernetes/tests/python_executable_check.py
# spark-3.5.5-bin-hadoop3/kubernetes/tests/worker_memory_check.py
# spark-3.5.5-bin-hadoop3/examples/
# spark-3.5.5-bin-hadoop3/examples/jars/
# spark-3.5.5-bin-hadoop3/examples/jars/scopt_2.12-3.7.1.jar
# spark-3.5.5-bin-hadoop3/examples/jars/spark-examples_2.12-3.5.5.jar
# spark-3.5.5-bin-hadoop3/examples/src/
# spark-3.5.5-bin-hadoop3/examples/src/main/
# spark-3.5.5-bin-hadoop3/examples/src/main/java/
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/JavaHdfsLR.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/JavaLogQuery.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/JavaPageRank.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/JavaSparkPi.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/JavaStatusTrackerDemo.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/JavaTC.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/JavaWordCount.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/JavaAFTSurvivalRegressionExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/JavaALSExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/JavaBinarizerExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/JavaBisectingKMeansExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/JavaBucketedRandomProjectionLSHExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/JavaBucketizerExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/JavaChiSqSelectorExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/JavaChiSquareTestExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/JavaCorrelationExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/JavaCountVectorizerExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/JavaDCTExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/JavaDecisionTreeClassificationExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/JavaDecisionTreeRegressionExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/JavaDocument.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/JavaElementwiseProductExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/JavaEstimatorTransformerParamExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/JavaFMClassifierExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/JavaFMRegressorExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/JavaFPGrowthExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/JavaFeatureHasherExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/JavaGaussianMixtureExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/JavaGeneralizedLinearRegressionExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/JavaGradientBoostedTreeClassifierExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/JavaGradientBoostedTreeRegressorExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/JavaImputerExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/JavaIndexToStringExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/JavaInteractionExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/JavaIsotonicRegressionExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/JavaKMeansExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/JavaLDAExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/JavaLabeledDocument.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/JavaLinearRegressionWithElasticNetExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/JavaLinearSVCExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/JavaLogisticRegressionSummaryExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/JavaLogisticRegressionWithElasticNetExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/JavaMaxAbsScalerExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/JavaMinHashLSHExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/JavaMinMaxScalerExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/JavaModelSelectionViaCrossValidationExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/JavaModelSelectionViaTrainValidationSplitExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/JavaMulticlassLogisticRegressionWithElasticNetExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/JavaMultilayerPerceptronClassifierExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/JavaNGramExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/JavaNaiveBayesExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/JavaNormalizerExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/JavaOneHotEncoderExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/JavaOneVsRestExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/JavaPCAExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/JavaPipelineExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/JavaPolynomialExpansionExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/JavaPowerIterationClusteringExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/JavaPrefixSpanExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/JavaQuantileDiscretizerExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/JavaRFormulaExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/JavaRandomForestClassifierExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/JavaRandomForestRegressorExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/JavaRobustScalerExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/JavaSQLTransformerExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/JavaStandardScalerExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/JavaStopWordsRemoverExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/JavaStringIndexerExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/JavaSummarizerExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/JavaTfIdfExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/JavaTokenizerExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/JavaUnivariateFeatureSelectorExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/JavaVarianceThresholdSelectorExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/JavaVectorAssemblerExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/JavaVectorIndexerExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/JavaVectorSizeHintExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/JavaVectorSlicerExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/ml/JavaWord2VecExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/mllib/
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/mllib/JavaALS.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/mllib/JavaAssociationRulesExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/mllib/JavaBinaryClassificationMetricsExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/mllib/JavaBisectingKMeansExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/mllib/JavaChiSqSelectorExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/mllib/JavaCorrelationsExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/mllib/JavaDecisionTreeClassificationExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/mllib/JavaDecisionTreeRegressionExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/mllib/JavaElementwiseProductExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/mllib/JavaGaussianMixtureExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/mllib/JavaGradientBoostingClassificationExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/mllib/JavaGradientBoostingRegressionExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/mllib/JavaHypothesisTestingExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/mllib/JavaHypothesisTestingKolmogorovSmirnovTestExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/mllib/JavaIsotonicRegressionExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/mllib/JavaKMeansExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/mllib/JavaKernelDensityEstimationExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/mllib/JavaLBFGSExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/mllib/JavaLatentDirichletAllocationExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/mllib/JavaLogisticRegressionWithLBFGSExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/mllib/JavaMultiLabelClassificationMetricsExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/mllib/JavaMulticlassClassificationMetricsExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/mllib/JavaNaiveBayesExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/mllib/JavaPCAExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/mllib/JavaPowerIterationClusteringExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/mllib/JavaPrefixSpanExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/mllib/JavaRandomForestClassificationExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/mllib/JavaRandomForestRegressionExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/mllib/JavaRankingMetricsExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/mllib/JavaRecommendationExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/mllib/JavaSVDExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/mllib/JavaSVMWithSGDExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/mllib/JavaSimpleFPGrowth.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/mllib/JavaStratifiedSamplingExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/mllib/JavaStreamingTestExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/mllib/JavaSummaryStatisticsExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/sql/
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/sql/JavaSparkSQLExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/sql/JavaUserDefinedScalar.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/sql/JavaUserDefinedTypedAggregation.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/sql/JavaUserDefinedUntypedAggregation.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/sql/hive/
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/sql/hive/JavaSparkHiveExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/sql/streaming/
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/sql/streaming/JavaStructuredComplexSessionization.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/sql/streaming/JavaStructuredKafkaWordCount.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/sql/streaming/JavaStructuredKerberizedKafkaWordCount.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/sql/streaming/JavaStructuredNetworkWordCount.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/sql/streaming/JavaStructuredNetworkWordCountWindowed.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/sql/streaming/JavaStructuredSessionization.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/sql/JavaSQLDataSourceExample.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/streaming/
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/streaming/JavaCustomReceiver.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/streaming/JavaDirectKafkaWordCount.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/streaming/JavaDirectKerberizedKafkaWordCount.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/streaming/JavaNetworkWordCount.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/streaming/JavaQueueStream.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/streaming/JavaRecord.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/streaming/JavaSqlNetworkWordCount.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/streaming/JavaStatefulNetworkWordCount.java
# spark-3.5.5-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/streaming/JavaRecoverableNetworkWordCount.java
# spark-3.5.5-bin-hadoop3/examples/src/main/python/
# spark-3.5.5-bin-hadoop3/examples/src/main/python/__init__.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/als.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/kmeans.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/logistic_regression.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/__init__,py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/aft_survival_regression.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/als_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/binarizer_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/bisecting_k_means_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/bucketed_random_projection_lsh_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/bucketizer_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/chi_square_test_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/chisq_selector_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/correlation_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/count_vectorizer_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/cross_validator.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/dataframe_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/dct_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/decision_tree_classification_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/decision_tree_regression_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/elementwise_product_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/estimator_transformer_param_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/feature_hasher_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/fm_classifier_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/fm_regressor_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/fpgrowth_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/gaussian_mixture_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/generalized_linear_regression_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/gradient_boosted_tree_classifier_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/gradient_boosted_tree_regressor_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/imputer_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/index_to_string_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/interaction_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/isotonic_regression_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/kmeans_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/lda_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/linear_regression_with_elastic_net.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/linearsvc.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/logistic_regression_summary_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/logistic_regression_with_elastic_net.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/max_abs_scaler_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/min_hash_lsh_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/min_max_scaler_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/multiclass_logistic_regression_with_elastic_net.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/multilayer_perceptron_classification.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/n_gram_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/naive_bayes_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/normalizer_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/one_vs_rest_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/onehot_encoder_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/pca_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/pipeline_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/polynomial_expansion_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/power_iteration_clustering_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/prefixspan_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/quantile_discretizer_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/random_forest_classifier_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/random_forest_regressor_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/rformula_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/robust_scaler_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/sql_transformer.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/standard_scaler_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/stopwords_remover_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/string_indexer_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/summarizer_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/tf_idf_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/tokenizer_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/train_validation_split.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/univariate_feature_selector_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/variance_threshold_selector_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/vector_assembler_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/vector_indexer_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/vector_size_hint_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/vector_slicer_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/ml/word2vec_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/mllib/
# spark-3.5.5-bin-hadoop3/examples/src/main/python/mllib/__init__.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/mllib/binary_classification_metrics_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/mllib/bisecting_k_means_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/mllib/correlations.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/mllib/correlations_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/mllib/decision_tree_classification_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/mllib/decision_tree_regression_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/mllib/elementwise_product_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/mllib/fpgrowth_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/mllib/gaussian_mixture_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/mllib/gaussian_mixture_model.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/mllib/gradient_boosting_classification_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/mllib/gradient_boosting_regression_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/mllib/hypothesis_testing_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/mllib/hypothesis_testing_kolmogorov_smirnov_test_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/mllib/isotonic_regression_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/mllib/k_means_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/mllib/kernel_density_estimation_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/mllib/kmeans.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/mllib/latent_dirichlet_allocation_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/mllib/linear_regression_with_sgd_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/mllib/logistic_regression.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/mllib/logistic_regression_with_lbfgs_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/mllib/multi_class_metrics_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/mllib/multi_label_metrics_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/mllib/naive_bayes_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/mllib/normalizer_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/mllib/pca_rowmatrix_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/mllib/power_iteration_clustering_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/mllib/random_forest_classification_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/mllib/random_forest_regression_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/mllib/random_rdd_generation.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/mllib/ranking_metrics_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/mllib/recommendation_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/mllib/regression_metrics_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/mllib/sampled_rdds.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/mllib/standard_scaler_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/mllib/stratified_sampling_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/mllib/streaming_k_means_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/mllib/streaming_linear_regression_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/mllib/summary_statistics_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/mllib/svd_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/mllib/svm_with_sgd_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/mllib/tf_idf_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/mllib/word2vec.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/mllib/word2vec_example.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/pagerank.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/pi.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/sql/
# spark-3.5.5-bin-hadoop3/examples/src/main/python/sql/__init__.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/sql/basic.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/sql/hive.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/sql/streaming/
# spark-3.5.5-bin-hadoop3/examples/src/main/python/sql/streaming/__init__,py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/sql/streaming/structured_kafka_wordcount.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/sql/streaming/structured_network_wordcount.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/sql/streaming/structured_network_wordcount_session_window.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/sql/streaming/structured_network_wordcount_windowed.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/sql/streaming/structured_sessionization.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/sql/arrow.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/sql/datasource.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/sql/udtf.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/status_api_demo.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/streaming/
# spark-3.5.5-bin-hadoop3/examples/src/main/python/streaming/__init__.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/streaming/hdfs_wordcount.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/streaming/network_wordcount.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/streaming/queue_stream.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/streaming/stateful_network_wordcount.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/streaming/network_wordjoinsentiments.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/streaming/recoverable_network_wordcount.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/streaming/sql_network_wordcount.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/transitive_closure.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/wordcount.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/avro_inputformat.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/parquet_inputformat.py
# spark-3.5.5-bin-hadoop3/examples/src/main/python/sort.py
# spark-3.5.5-bin-hadoop3/examples/src/main/r/
# spark-3.5.5-bin-hadoop3/examples/src/main/r/RSparkSQLExample.R
# spark-3.5.5-bin-hadoop3/examples/src/main/r/data-manipulation.R
# spark-3.5.5-bin-hadoop3/examples/src/main/r/dataframe.R
# spark-3.5.5-bin-hadoop3/examples/src/main/r/ml/
# spark-3.5.5-bin-hadoop3/examples/src/main/r/ml/als.R
# spark-3.5.5-bin-hadoop3/examples/src/main/r/ml/bisectingKmeans.R
# spark-3.5.5-bin-hadoop3/examples/src/main/r/ml/decisionTree.R
# spark-3.5.5-bin-hadoop3/examples/src/main/r/ml/fmClassifier.R
# spark-3.5.5-bin-hadoop3/examples/src/main/r/ml/fmRegressor.R
# spark-3.5.5-bin-hadoop3/examples/src/main/r/ml/fpm.R
# spark-3.5.5-bin-hadoop3/examples/src/main/r/ml/gaussianMixture.R
# spark-3.5.5-bin-hadoop3/examples/src/main/r/ml/gbt.R
# spark-3.5.5-bin-hadoop3/examples/src/main/r/ml/glm.R
# spark-3.5.5-bin-hadoop3/examples/src/main/r/ml/isoreg.R
# spark-3.5.5-bin-hadoop3/examples/src/main/r/ml/kmeans.R
# spark-3.5.5-bin-hadoop3/examples/src/main/r/ml/kstest.R
# spark-3.5.5-bin-hadoop3/examples/src/main/r/ml/lda.R
# spark-3.5.5-bin-hadoop3/examples/src/main/r/ml/lm_with_elastic_net.R
# spark-3.5.5-bin-hadoop3/examples/src/main/r/ml/logit.R
# spark-3.5.5-bin-hadoop3/examples/src/main/r/ml/ml.R
# spark-3.5.5-bin-hadoop3/examples/src/main/r/ml/mlp.R
# spark-3.5.5-bin-hadoop3/examples/src/main/r/ml/naiveBayes.R
# spark-3.5.5-bin-hadoop3/examples/src/main/r/ml/powerIterationClustering.R
# spark-3.5.5-bin-hadoop3/examples/src/main/r/ml/prefixSpan.R
# spark-3.5.5-bin-hadoop3/examples/src/main/r/ml/randomForest.R
# spark-3.5.5-bin-hadoop3/examples/src/main/r/ml/survreg.R
# spark-3.5.5-bin-hadoop3/examples/src/main/r/ml/svmLinear.R
# spark-3.5.5-bin-hadoop3/examples/src/main/r/streaming/
# spark-3.5.5-bin-hadoop3/examples/src/main/r/streaming/structured_network_wordcount.R
# spark-3.5.5-bin-hadoop3/examples/src/main/resources/
# spark-3.5.5-bin-hadoop3/examples/src/main/resources/META-INF/
# spark-3.5.5-bin-hadoop3/examples/src/main/resources/META-INF/services/
# spark-3.5.5-bin-hadoop3/examples/src/main/resources/META-INF/services/org.apache.spark.sql.SparkSessionExtensionsProvider
# spark-3.5.5-bin-hadoop3/examples/src/main/resources/META-INF/services/org.apache.spark.sql.jdbc.JdbcConnectionProvider
# spark-3.5.5-bin-hadoop3/examples/src/main/resources/dir1/
# spark-3.5.5-bin-hadoop3/examples/src/main/resources/dir1/dir2/
# spark-3.5.5-bin-hadoop3/examples/src/main/resources/dir1/dir2/file2.parquet
# spark-3.5.5-bin-hadoop3/examples/src/main/resources/dir1/file1.parquet
# spark-3.5.5-bin-hadoop3/examples/src/main/resources/dir1/file3.json
# spark-3.5.5-bin-hadoop3/examples/src/main/resources/employees.json
# spark-3.5.5-bin-hadoop3/examples/src/main/resources/full_user.avsc
# spark-3.5.5-bin-hadoop3/examples/src/main/resources/kv1.txt
# spark-3.5.5-bin-hadoop3/examples/src/main/resources/people.csv
# spark-3.5.5-bin-hadoop3/examples/src/main/resources/people.json
# spark-3.5.5-bin-hadoop3/examples/src/main/resources/people.txt
# spark-3.5.5-bin-hadoop3/examples/src/main/resources/user.avsc
# spark-3.5.5-bin-hadoop3/examples/src/main/resources/users.avro
# spark-3.5.5-bin-hadoop3/examples/src/main/resources/users.orc
# spark-3.5.5-bin-hadoop3/examples/src/main/resources/users.parquet
# spark-3.5.5-bin-hadoop3/examples/src/main/scala/
# spark-3.5.5-bin-hadoop3/examples/src/main/scala/org/
# spark-3.5.5-bin-hadoop3/examples/src/main/scala/org/apache/
# spark-3.5.5-bin-hadoop3/examples/src/main/scala/org/apache/spark/
# spark-3.5.5-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/
# spark-3.5.5-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/AccumulatorMetricsTest.scala
# spark-3.5.5-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/BroadcastTest.scala
# spark-3.5.5-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/LocalFileLR.scala
# ...
# spark-3.5.5-bin-hadoop3/python/pyspark/sql/tests/connect/test_session.py
# spark-3.5.5-bin-hadoop3/python/pyspark/sql/tests/connect/test_utils.py
# spark-3.5.5-bin-hadoop3/python/pyspark/sql/tests/pandas/
# spark-3.5.5-bin-hadoop3/python/pyspark/sql/tests/pandas/__init__.py
# spark-3.5.5-bin-hadoop3/python/pyspark/sql/tests/pandas/test_pandas_cogrouped_map.py
# spark-3.5.5-bin-hadoop3/python/pyspark/sql/tests/pandas/test_pandas_grouped_map.py
# spark-3.5.5-bin-hadoop3/python/pyspark/sql/tests/pandas/test_pandas_grouped_map_with_state.py
# spark-3.5.5-bin-hadoop3/python/pyspark/sql/tests/pandas/test_pandas_map.py
# spark-3.5.5-bin-hadoop3/python/pyspark/sql/tests/pandas/test_pandas_udf.py
# spark-3.5.5-bin-hadoop3/python/pyspark/sql/tests/pandas/test_pandas_udf_grouped_agg.py
# spark-3.5.5-bin-hadoop3/python/pyspark/sql/tests/pandas/test_pandas_udf_scalar.py
# spark-3.5.5-bin-hadoop3/python/pyspark/sql/tests/pandas/test_pandas_udf_typehints.py
# spark-3.5.5-bin-hadoop3/python/pyspark/sql/tests/pandas/test_pandas_udf_typehints_with_future_annotations.py
# spark-3.5.5-bin-hadoop3/python/pyspark/sql/tests/pandas/test_pandas_udf_window.py
# spark-3.5.5-bin-hadoop3/python/pyspark/sql/tests/streaming/
# spark-3.5.5-bin-hadoop3/python/pyspark/sql/tests/streaming/__init__.py
# spark-3.5.5-bin-hadoop3/python/pyspark/sql/tests/streaming/test_streaming.py
# spark-3.5.5-bin-hadoop3/python/pyspark/sql/tests/streaming/test_streaming_foreach.py
# spark-3.5.5-bin-hadoop3/python/pyspark/sql/tests/streaming/test_streaming_foreach_batch.py
# spark-3.5.5-bin-hadoop3/python/pyspark/sql/tests/streaming/test_streaming_listener.py
# spark-3.5.5-bin-hadoop3/python/pyspark/sql/tests/test_errors.py
# spark-3.5.5-bin-hadoop3/python/pyspark/sql/tests/typing/
# spark-3.5.5-bin-hadoop3/python/pyspark/sql/tests/typing/test_column.yml
# spark-3.5.5-bin-hadoop3/python/pyspark/sql/tests/typing/test_udf.yml
# spark-3.5.5-bin-hadoop3/python/pyspark/sql/tests/typing/test_dataframe.yml
# spark-3.5.5-bin-hadoop3/python/pyspark/sql/tests/typing/test_functions.yml
# spark-3.5.5-bin-hadoop3/python/pyspark/sql/tests/typing/test_readwriter.yml
# spark-3.5.5-bin-hadoop3/python/pyspark/sql/tests/typing/test_session.yml
# spark-3.5.5-bin-hadoop3/python/pyspark/sql/tests/test_arrow.py
# spark-3.5.5-bin-hadoop3/python/pyspark/sql/tests/test_arrow_map.py
# spark-3.5.5-bin-hadoop3/python/pyspark/sql/tests/test_arrow_python_udf.py
# spark-3.5.5-bin-hadoop3/python/pyspark/sql/tests/test_catalog.py
# spark-3.5.5-bin-hadoop3/python/pyspark/sql/tests/test_column.py
# spark-3.5.5-bin-hadoop3/python/pyspark/sql/tests/test_conf.py
# spark-3.5.5-bin-hadoop3/python/pyspark/sql/tests/test_context.py
# spark-3.5.5-bin-hadoop3/python/pyspark/sql/tests/test_dataframe.py
# spark-3.5.5-bin-hadoop3/python/pyspark/sql/tests/test_datasources.py
# spark-3.5.5-bin-hadoop3/python/pyspark/sql/tests/test_functions.py
# spark-3.5.5-bin-hadoop3/python/pyspark/sql/tests/test_group.py
# spark-3.5.5-bin-hadoop3/python/pyspark/sql/tests/test_pandas_sqlmetrics.py
# spark-3.5.5-bin-hadoop3/python/pyspark/sql/tests/test_readwriter.py
# spark-3.5.5-bin-hadoop3/python/pyspark/sql/tests/test_serde.py
# spark-3.5.5-bin-hadoop3/python/pyspark/sql/tests/test_session.py
# spark-3.5.5-bin-hadoop3/python/pyspark/sql/tests/test_types.py
# spark-3.5.5-bin-hadoop3/python/pyspark/sql/tests/test_udf.py
# spark-3.5.5-bin-hadoop3/python/pyspark/sql/tests/test_udf_profiler.py
# spark-3.5.5-bin-hadoop3/python/pyspark/sql/tests/test_udtf.py
# spark-3.5.5-bin-hadoop3/python/pyspark/sql/tests/test_utils.py
# spark-3.5.5-bin-hadoop3/python/pyspark/sql/__init__.py
# spark-3.5.5-bin-hadoop3/python/pyspark/sql/_typing.pyi
# spark-3.5.5-bin-hadoop3/python/pyspark/sql/catalog.py
# spark-3.5.5-bin-hadoop3/python/pyspark/sql/column.py
# spark-3.5.5-bin-hadoop3/python/pyspark/sql/conf.py
# spark-3.5.5-bin-hadoop3/python/pyspark/sql/context.py
# spark-3.5.5-bin-hadoop3/python/pyspark/sql/dataframe.py
# spark-3.5.5-bin-hadoop3/python/pyspark/sql/functions.py
# spark-3.5.5-bin-hadoop3/python/pyspark/sql/group.py
# spark-3.5.5-bin-hadoop3/python/pyspark/sql/observation.py
# spark-3.5.5-bin-hadoop3/python/pyspark/sql/readwriter.py
# spark-3.5.5-bin-hadoop3/python/pyspark/sql/session.py
# spark-3.5.5-bin-hadoop3/python/pyspark/sql/sql_formatter.py
# spark-3.5.5-bin-hadoop3/python/pyspark/sql/types.py
# spark-3.5.5-bin-hadoop3/python/pyspark/sql/udf.py
# spark-3.5.5-bin-hadoop3/python/pyspark/sql/udtf.py
# spark-3.5.5-bin-hadoop3/python/pyspark/sql/utils.py
# spark-3.5.5-bin-hadoop3/python/pyspark/sql/window.py
# spark-3.5.5-bin-hadoop3/python/pyspark/statcounter.py
# spark-3.5.5-bin-hadoop3/python/pyspark/storagelevel.py
# spark-3.5.5-bin-hadoop3/python/pyspark/streaming/
# spark-3.5.5-bin-hadoop3/python/pyspark/streaming/__init__.py
# spark-3.5.5-bin-hadoop3/python/pyspark/streaming/kinesis.py
# spark-3.5.5-bin-hadoop3/python/pyspark/streaming/listener.py
# spark-3.5.5-bin-hadoop3/python/pyspark/streaming/tests/
# spark-3.5.5-bin-hadoop3/python/pyspark/streaming/tests/__init__.py
# spark-3.5.5-bin-hadoop3/python/pyspark/streaming/tests/test_kinesis.py
# spark-3.5.5-bin-hadoop3/python/pyspark/streaming/tests/test_context.py
# spark-3.5.5-bin-hadoop3/python/pyspark/streaming/tests/test_dstream.py
# spark-3.5.5-bin-hadoop3/python/pyspark/streaming/tests/test_listener.py
# spark-3.5.5-bin-hadoop3/python/pyspark/streaming/util.py
# spark-3.5.5-bin-hadoop3/python/pyspark/streaming/context.py
# spark-3.5.5-bin-hadoop3/python/pyspark/streaming/dstream.py
# spark-3.5.5-bin-hadoop3/python/pyspark/testing/
# spark-3.5.5-bin-hadoop3/python/pyspark/testing/mllibutils.py
# spark-3.5.5-bin-hadoop3/python/pyspark/testing/__init__.py
# spark-3.5.5-bin-hadoop3/python/pyspark/testing/connectutils.py
# spark-3.5.5-bin-hadoop3/python/pyspark/testing/mlutils.py
# spark-3.5.5-bin-hadoop3/python/pyspark/testing/pandasutils.py
# spark-3.5.5-bin-hadoop3/python/pyspark/testing/sqlutils.py
# spark-3.5.5-bin-hadoop3/python/pyspark/testing/streamingutils.py
# spark-3.5.5-bin-hadoop3/python/pyspark/testing/utils.py
# spark-3.5.5-bin-hadoop3/python/pyspark/tests/
# spark-3.5.5-bin-hadoop3/python/pyspark/tests/__init__.py
# spark-3.5.5-bin-hadoop3/python/pyspark/tests/test_broadcast.py
# spark-3.5.5-bin-hadoop3/python/pyspark/tests/test_conf.py
# spark-3.5.5-bin-hadoop3/python/pyspark/tests/test_daemon.py
# spark-3.5.5-bin-hadoop3/python/pyspark/tests/test_join.py
# spark-3.5.5-bin-hadoop3/python/pyspark/tests/test_rddbarrier.py
# spark-3.5.5-bin-hadoop3/python/pyspark/tests/test_rddsampler.py
# spark-3.5.5-bin-hadoop3/python/pyspark/tests/test_serializers.py
# spark-3.5.5-bin-hadoop3/python/pyspark/tests/test_stage_sched.py
# spark-3.5.5-bin-hadoop3/python/pyspark/tests/typing/
# spark-3.5.5-bin-hadoop3/python/pyspark/tests/typing/test_context.yml
# spark-3.5.5-bin-hadoop3/python/pyspark/tests/typing/test_core.yml
# spark-3.5.5-bin-hadoop3/python/pyspark/tests/typing/test_resultiterable.yml
# spark-3.5.5-bin-hadoop3/python/pyspark/tests/typing/test_rdd.yml
# spark-3.5.5-bin-hadoop3/python/pyspark/tests/test_appsubmit.py
# spark-3.5.5-bin-hadoop3/python/pyspark/tests/test_context.py
# spark-3.5.5-bin-hadoop3/python/pyspark/tests/test_install_spark.py
# spark-3.5.5-bin-hadoop3/python/pyspark/tests/test_memory_profiler.py
# spark-3.5.5-bin-hadoop3/python/pyspark/tests/test_pin_thread.py
# spark-3.5.5-bin-hadoop3/python/pyspark/tests/test_profiler.py
# spark-3.5.5-bin-hadoop3/python/pyspark/tests/test_rdd.py
# spark-3.5.5-bin-hadoop3/python/pyspark/tests/test_readwrite.py
# spark-3.5.5-bin-hadoop3/python/pyspark/tests/test_shuffle.py
# spark-3.5.5-bin-hadoop3/python/pyspark/tests/test_statcounter.py
# spark-3.5.5-bin-hadoop3/python/pyspark/tests/test_taskcontext.py
# spark-3.5.5-bin-hadoop3/python/pyspark/tests/test_util.py
# spark-3.5.5-bin-hadoop3/python/pyspark/tests/test_worker.py
# spark-3.5.5-bin-hadoop3/python/pyspark/__init__.py
# spark-3.5.5-bin-hadoop3/python/pyspark/accumulators.py
# spark-3.5.5-bin-hadoop3/python/pyspark/broadcast.py
# spark-3.5.5-bin-hadoop3/python/pyspark/conf.py
# spark-3.5.5-bin-hadoop3/python/pyspark/context.py
# spark-3.5.5-bin-hadoop3/python/pyspark/daemon.py
# spark-3.5.5-bin-hadoop3/python/pyspark/files.py
# spark-3.5.5-bin-hadoop3/python/pyspark/install.py
# spark-3.5.5-bin-hadoop3/python/pyspark/instrumentation_utils.py
# spark-3.5.5-bin-hadoop3/python/pyspark/java_gateway.py
# spark-3.5.5-bin-hadoop3/python/pyspark/join.py
# spark-3.5.5-bin-hadoop3/python/pyspark/profiler.py
# spark-3.5.5-bin-hadoop3/python/pyspark/rdd.py
# spark-3.5.5-bin-hadoop3/python/pyspark/serializers.py
# spark-3.5.5-bin-hadoop3/python/pyspark/shell.py
# spark-3.5.5-bin-hadoop3/python/pyspark/shuffle.py
# spark-3.5.5-bin-hadoop3/python/pyspark/status.py
# spark-3.5.5-bin-hadoop3/python/pyspark/taskcontext.py
# spark-3.5.5-bin-hadoop3/python/pyspark/traceback_utils.py
# spark-3.5.5-bin-hadoop3/python/pyspark/util.py
# spark-3.5.5-bin-hadoop3/python/pyspark/version.py
# spark-3.5.5-bin-hadoop3/python/pyspark/worker.py
# spark-3.5.5-bin-hadoop3/python/pyspark/worker_util.py
# spark-3.5.5-bin-hadoop3/python/pyspark/__pycache__/
# spark-3.5.5-bin-hadoop3/python/pyspark/__pycache__/install.cpython-38.pyc
# spark-3.5.5-bin-hadoop3/python/pyspark/python/
# spark-3.5.5-bin-hadoop3/python/pyspark/python/pyspark/
# spark-3.5.5-bin-hadoop3/python/pyspark/python/pyspark/shell.py
# spark-3.5.5-bin-hadoop3/python/test_coverage/
# spark-3.5.5-bin-hadoop3/python/test_coverage/sitecustomize.py
# spark-3.5.5-bin-hadoop3/python/test_coverage/conf/
# spark-3.5.5-bin-hadoop3/python/test_coverage/conf/spark-defaults.conf
# spark-3.5.5-bin-hadoop3/python/test_coverage/coverage_daemon.py
# spark-3.5.5-bin-hadoop3/python/test_support/
# spark-3.5.5-bin-hadoop3/python/test_support/SimpleHTTPServer.py
# spark-3.5.5-bin-hadoop3/python/test_support/hello/
# spark-3.5.5-bin-hadoop3/python/test_support/hello/hello.txt
# spark-3.5.5-bin-hadoop3/python/test_support/hello/sub_hello/
# spark-3.5.5-bin-hadoop3/python/test_support/hello/sub_hello/sub_hello.txt
# spark-3.5.5-bin-hadoop3/python/test_support/sql/
# spark-3.5.5-bin-hadoop3/python/test_support/sql/ages_newlines.csv
# spark-3.5.5-bin-hadoop3/python/test_support/sql/orc_partitioned/
# spark-3.5.5-bin-hadoop3/python/test_support/sql/orc_partitioned/_SUCCESS
# spark-3.5.5-bin-hadoop3/python/test_support/sql/orc_partitioned/b=0/
# spark-3.5.5-bin-hadoop3/python/test_support/sql/orc_partitioned/b=0/c=0/
# spark-3.5.5-bin-hadoop3/python/test_support/sql/orc_partitioned/b=0/c=0/.part-r-00000-829af031-b970-49d6-ad39-30460a0be2c8.orc.crc
# spark-3.5.5-bin-hadoop3/python/test_support/sql/orc_partitioned/b=0/c=0/part-r-00000-829af031-b970-49d6-ad39-30460a0be2c8.orc
# spark-3.5.5-bin-hadoop3/python/test_support/sql/orc_partitioned/b=1/
# spark-3.5.5-bin-hadoop3/python/test_support/sql/orc_partitioned/b=1/c=1/
# spark-3.5.5-bin-hadoop3/python/test_support/sql/orc_partitioned/b=1/c=1/.part-r-00000-829af031-b970-49d6-ad39-30460a0be2c8.orc.crc
# spark-3.5.5-bin-hadoop3/python/test_support/sql/orc_partitioned/b=1/c=1/part-r-00000-829af031-b970-49d6-ad39-30460a0be2c8.orc
# spark-3.5.5-bin-hadoop3/python/test_support/sql/people.json
# spark-3.5.5-bin-hadoop3/python/test_support/sql/people1.json
# spark-3.5.5-bin-hadoop3/python/test_support/sql/people_array.json
# spark-3.5.5-bin-hadoop3/python/test_support/sql/people_array_utf16le.json
# spark-3.5.5-bin-hadoop3/python/test_support/sql/streaming/
# spark-3.5.5-bin-hadoop3/python/test_support/sql/streaming/text-test.txt
# spark-3.5.5-bin-hadoop3/python/test_support/sql/text-test.txt
# spark-3.5.5-bin-hadoop3/python/test_support/test_pytorch_training_file.py
# spark-3.5.5-bin-hadoop3/python/test_support/userlib-0.1.zip
# spark-3.5.5-bin-hadoop3/python/test_support/userlibrary.py
# spark-3.5.5-bin-hadoop3/python/.gitignore
# spark-3.5.5-bin-hadoop3/python/MANIFEST.in
# spark-3.5.5-bin-hadoop3/python/README.md
# spark-3.5.5-bin-hadoop3/python/mypy.ini
# spark-3.5.5-bin-hadoop3/python/run-tests
# spark-3.5.5-bin-hadoop3/python/run-tests-with-coverage
# spark-3.5.5-bin-hadoop3/python/run-tests.py
# spark-3.5.5-bin-hadoop3/python/setup.cfg
# spark-3.5.5-bin-hadoop3/python/setup.py
# spark-3.5.5-bin-hadoop3/python/pyspark.egg-info/
# spark-3.5.5-bin-hadoop3/python/pyspark.egg-info/PKG-INFO
# spark-3.5.5-bin-hadoop3/python/pyspark.egg-info/dependency_links.txt
# spark-3.5.5-bin-hadoop3/python/pyspark.egg-info/requires.txt
# spark-3.5.5-bin-hadoop3/python/pyspark.egg-info/top_level.txt
# spark-3.5.5-bin-hadoop3/python/pyspark.egg-info/SOURCES.txt
# spark-3.5.5-bin-hadoop3/python/dist/
# spark-3.5.5-bin-hadoop3/sbin/
# spark-3.5.5-bin-hadoop3/sbin/decommission-worker.sh
# spark-3.5.5-bin-hadoop3/sbin/spark-daemons.sh
# spark-3.5.5-bin-hadoop3/sbin/start-all.sh
# spark-3.5.5-bin-hadoop3/sbin/start-workers.sh
# spark-3.5.5-bin-hadoop3/sbin/stop-all.sh
# spark-3.5.5-bin-hadoop3/sbin/stop-connect-server.sh
# spark-3.5.5-bin-hadoop3/sbin/stop-history-server.sh
# spark-3.5.5-bin-hadoop3/sbin/stop-master.sh
# spark-3.5.5-bin-hadoop3/sbin/stop-thriftserver.sh
# spark-3.5.5-bin-hadoop3/sbin/stop-worker.sh
# spark-3.5.5-bin-hadoop3/sbin/stop-workers.sh
# spark-3.5.5-bin-hadoop3/sbin/workers.sh
# spark-3.5.5-bin-hadoop3/sbin/decommission-slave.sh
# spark-3.5.5-bin-hadoop3/sbin/slaves.sh
# spark-3.5.5-bin-hadoop3/sbin/spark-config.sh
# spark-3.5.5-bin-hadoop3/sbin/spark-daemon.sh
# spark-3.5.5-bin-hadoop3/sbin/start-connect-server.sh
# spark-3.5.5-bin-hadoop3/sbin/start-history-server.sh
# spark-3.5.5-bin-hadoop3/sbin/start-master.sh
# spark-3.5.5-bin-hadoop3/sbin/start-mesos-dispatcher.sh
# spark-3.5.5-bin-hadoop3/sbin/start-mesos-shuffle-service.sh
# spark-3.5.5-bin-hadoop3/sbin/start-slave.sh
# spark-3.5.5-bin-hadoop3/sbin/start-slaves.sh
# spark-3.5.5-bin-hadoop3/sbin/start-thriftserver.sh
# spark-3.5.5-bin-hadoop3/sbin/start-worker.sh
# spark-3.5.5-bin-hadoop3/sbin/stop-mesos-dispatcher.sh
# spark-3.5.5-bin-hadoop3/sbin/stop-mesos-shuffle-service.sh
# spark-3.5.5-bin-hadoop3/sbin/stop-slave.sh
# spark-3.5.5-bin-hadoop3/sbin/stop-slaves.sh
# spark-3.5.5-bin-hadoop3/R/
# spark-3.5.5-bin-hadoop3/R/lib/
# spark-3.5.5-bin-hadoop3/R/lib/SparkR/
# spark-3.5.5-bin-hadoop3/R/lib/SparkR/NAMESPACE
# spark-3.5.5-bin-hadoop3/R/lib/SparkR/DESCRIPTION
# spark-3.5.5-bin-hadoop3/R/lib/SparkR/Meta/
# spark-3.5.5-bin-hadoop3/R/lib/SparkR/Meta/package.rds
# spark-3.5.5-bin-hadoop3/R/lib/SparkR/Meta/features.rds
# spark-3.5.5-bin-hadoop3/R/lib/SparkR/Meta/Rd.rds
# spark-3.5.5-bin-hadoop3/R/lib/SparkR/Meta/hsearch.rds
# spark-3.5.5-bin-hadoop3/R/lib/SparkR/Meta/links.rds
# spark-3.5.5-bin-hadoop3/R/lib/SparkR/Meta/vignette.rds
# spark-3.5.5-bin-hadoop3/R/lib/SparkR/Meta/nsInfo.rds
# spark-3.5.5-bin-hadoop3/R/lib/SparkR/R/
# spark-3.5.5-bin-hadoop3/R/lib/SparkR/R/SparkR
# spark-3.5.5-bin-hadoop3/R/lib/SparkR/R/SparkR.rdb
# spark-3.5.5-bin-hadoop3/R/lib/SparkR/R/SparkR.rdx
# spark-3.5.5-bin-hadoop3/R/lib/SparkR/doc/
# spark-3.5.5-bin-hadoop3/R/lib/SparkR/doc/sparkr-vignettes.R
# spark-3.5.5-bin-hadoop3/R/lib/SparkR/doc/sparkr-vignettes.Rmd
# spark-3.5.5-bin-hadoop3/R/lib/SparkR/doc/sparkr-vignettes.html
# spark-3.5.5-bin-hadoop3/R/lib/SparkR/doc/index.html
# spark-3.5.5-bin-hadoop3/R/lib/SparkR/profile/
# spark-3.5.5-bin-hadoop3/R/lib/SparkR/profile/general.R
# spark-3.5.5-bin-hadoop3/R/lib/SparkR/profile/shell.R
# spark-3.5.5-bin-hadoop3/R/lib/SparkR/tests/
# spark-3.5.5-bin-hadoop3/R/lib/SparkR/tests/testthat/
# spark-3.5.5-bin-hadoop3/R/lib/SparkR/tests/testthat/test_basic.R
# spark-3.5.5-bin-hadoop3/R/lib/SparkR/worker/
# spark-3.5.5-bin-hadoop3/R/lib/SparkR/worker/daemon.R
# spark-3.5.5-bin-hadoop3/R/lib/SparkR/worker/worker.R
# spark-3.5.5-bin-hadoop3/R/lib/SparkR/help/
# spark-3.5.5-bin-hadoop3/R/lib/SparkR/help/paths.rds
# spark-3.5.5-bin-hadoop3/R/lib/SparkR/help/SparkR.rdb
# spark-3.5.5-bin-hadoop3/R/lib/SparkR/help/SparkR.rdx
# spark-3.5.5-bin-hadoop3/R/lib/SparkR/help/AnIndex
# spark-3.5.5-bin-hadoop3/R/lib/SparkR/help/aliases.rds
# spark-3.5.5-bin-hadoop3/R/lib/SparkR/html/
# spark-3.5.5-bin-hadoop3/R/lib/SparkR/html/00Index.html
# spark-3.5.5-bin-hadoop3/R/lib/SparkR/html/R.css
# spark-3.5.5-bin-hadoop3/R/lib/SparkR/INDEX
# spark-3.5.5-bin-hadoop3/R/lib/sparkr.zip
# Requirement already satisfied: pyspark==3.5.5 in /usr/local/lib/python3.11/dist-packages (3.5.5)
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.11/dist-packages (from pyspark==3.5.5) (0.10.9.7)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pyspark
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName('DecisionTree').getOrCreate()

# %%
# CSV options
infer_schema = "false"
first_row_is_header = "true"
delimiter = ","
file_type = "csv"

df = spark.read.format(file_type) \
  .option("inferSchema", infer_schema) \
  .option("header", first_row_is_header) \
  .option("sep", delimiter).csv("/content/drive/MyDrive/HousingPriceRegression/Data/kc_house_data.csv")

# %%
df.show()
df.printSchema()
# Out:
# +----------+---------------+----------+--------+---------+-----------+--------+------+----------+----+---------+-----+----------+-------------+--------+------------+-------+-------+--------+-------------+----------+
# |        id|           date|     price|bedrooms|bathrooms|sqft_living|sqft_lot|floors|waterfront|view|condition|grade|sqft_above|sqft_basement|yr_built|yr_renovated|zipcode|    lat|    long|sqft_living15|sqft_lot15|
# +----------+---------------+----------+--------+---------+-----------+--------+------+----------+----+---------+-----+----------+-------------+--------+------------+-------+-------+--------+-------------+----------+
# |7129300520|20141013T000000|    221900|       3|        1|       1180|    5650|     1|         0|   0|        3|    7|      1180|            0|    1955|           0|  98178|47.5112|-122.257|         1340|      5650|
# |6414100192|20141209T000000|    538000|       3|     2.25|       2570|    7242|     2|         0|   0|        3|    7|      2170|          400|    1951|        1991|  98125| 47.721|-122.319|         1690|      7639|
# |5631500400|20150225T000000|    180000|       2|        1|        770|   10000|     1|         0|   0|        3|    6|       770|            0|    1933|           0|  98028|47.7379|-122.233|         2720|      8062|
# |2487200875|20141209T000000|    604000|       4|        3|       1960|    5000|     1|         0|   0|        5|    7|      1050|          910|    1965|           0|  98136|47.5208|-122.393|         1360|      5000|
# |1954400510|20150218T000000|    510000|       3|        2|       1680|    8080|     1|         0|   0|        3|    8|      1680|            0|    1987|           0|  98074|47.6168|-122.045|         1800|      7503|
# |7237550310|20140512T000000|1.225e+006|       4|      4.5|       5420|  101930|     1|         0|   0|        3|   11|      3890|         1530|    2001|           0|  98053|47.6561|-122.005|         4760|    101930|
# |1321400060|20140627T000000|    257500|       3|     2.25|       1715|    6819|     2|         0|   0|        3|    7|      1715|            0|    1995|           0|  98003|47.3097|-122.327|         2238|      6819|
# |2008000270|20150115T000000|    291850|       3|      1.5|       1060|    9711|     1|         0|   0|        3|    7|      1060|            0|    1963|           0|  98198|47.4095|-122.315|         1650|      9711|
# |2414600126|20150415T000000|    229500|       3|        1|       1780|    7470|     1|         0|   0|        3|    7|      1050|          730|    1960|           0|  98146|47.5123|-122.337|         1780|      8113|
# |3793500160|20150312T000000|    323000|       3|      2.5|       1890|    6560|     2|         0|   0|        3|    7|      1890|            0|    2003|           0|  98038|47.3684|-122.031|         2390|      7570|
# |1736800520|20150403T000000|    662500|       3|      2.5|       3560|    9796|     1|         0|   0|        3|    8|      1860|         1700|    1965|           0|  98007|47.6007|-122.145|         2210|      8925|
# |9212900260|20140527T000000|    468000|       2|        1|       1160|    6000|     1|         0|   0|        4|    7|       860|          300|    1942|           0|  98115|  47.69|-122.292|         1330|      6000|
# |0114101516|20140528T000000|    310000|       3|        1|       1430|   19901|   1.5|         0|   0|        4|    7|      1430|            0|    1927|           0|  98028|47.7558|-122.229|         1780|     12697|
# |6054650070|20141007T000000|    400000|       3|     1.75|       1370|    9680|     1|         0|   0|        4|    7|      1370|            0|    1977|           0|  98074|47.6127|-122.045|         1370|     10208|
# |1175000570|20150312T000000|    530000|       5|        2|       1810|    4850|   1.5|         0|   0|        3|    7|      1810|            0|    1900|           0|  98107|  47.67|-122.394|         1360|      4850|
# |9297300055|20150124T000000|    650000|       4|        3|       2950|    5000|     2|         0|   3|        3|    9|      1980|          970|    1979|           0|  98126|47.5714|-122.375|         2140|      4000|
# |1875500060|20140731T000000|    395000|       3|        2|       1890|   14040|     2|         0|   0|        3|    7|      1890|            0|    1994|           0|  98019|47.7277|-121.962|         1890|     14018|
# |6865200140|20140529T000000|    485000|       4|        1|       1600|    4300|   1.5|         0|   0|        4|    7|      1600|            0|    1916|           0|  98103|47.6648|-122.343|         1610|      4300|
# |0016000397|20141205T000000|    189000|       2|        1|       1200|    9850|     1|         0|   0|        4|    7|      1200|            0|    1921|           0|  98002|47.3089| -122.21|         1060|      5095|
# |7983200060|20150424T000000|    230000|       3|        1|       1250|    9774|     1|         0|   0|        4|    7|      1250|            0|    1969|           0|  98003|47.3343|-122.306|         1280|      8850|
# +----------+---------------+----------+--------+---------+-----------+--------+------+----------+----+---------+-----+----------+-------------+--------+------------+-------+-------+--------+-------------+----------+
# only showing top 20 rows
#
# root
#  |-- id: string (nullable = true)
#  |-- date: string (nullable = true)
#  |-- price: string (nullable = true)
#  |-- bedrooms: string (nullable = true)
#  |-- bathrooms: string (nullable = true)
#  |-- sqft_living: string (nullable = true)
#  |-- sqft_lot: string (nullable = true)
#  |-- floors: string (nullable = true)
#  |-- waterfront: string (nullable = true)
#  |-- view: string (nullable = true)
#  |-- condition: string (nullable = true)
#  |-- grade: string (nullable = true)
#  |-- sqft_above: string (nullable = true)
#  |-- sqft_basement: string (nullable = true)
#  |-- yr_built: string (nullable = true)
#  |-- yr_renovated: string (nullable = true)
#  |-- zipcode: string (nullable = true)
#  |-- lat: string (nullable = true)
#  |-- long: string (nullable = true)
#  |-- sqft_living15: string (nullable = true)
#  |-- sqft_lot15: string (nullable = true)

# %%
from pyspark.sql.functions import col, to_date
from pyspark.sql.types import IntegerType
from pyspark.sql.types import DoubleType

integer_columns = ['id', 'bedrooms', 'sqft_living', 'sqft_lot', 'waterfront', 'view', 'condition', 'grade', 'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'sqft_living15', 'sqft_lot15']
double_columns = ['price', 'bathrooms', 'floors', 'lat', 'long']

for column in integer_columns:
  df = df.withColumn(column, col(column).cast(IntegerType()))

for column in double_columns:
  df = df.withColumn(column, col(column).cast(DoubleType()))

df = df.withColumn('date', to_date(col('date'), 'yyyy-MM-dd'))

df.printSchema()
# Out:
# root
#  |-- id: integer (nullable = true)
#  |-- date: date (nullable = true)
#  |-- price: double (nullable = true)
#  |-- bedrooms: integer (nullable = true)
#  |-- bathrooms: double (nullable = true)
#  |-- sqft_living: integer (nullable = true)
#  |-- sqft_lot: integer (nullable = true)
#  |-- floors: double (nullable = true)
#  |-- waterfront: integer (nullable = true)
#  |-- view: integer (nullable = true)
#  |-- condition: integer (nullable = true)
#  |-- grade: integer (nullable = true)
#  |-- sqft_above: integer (nullable = true)
#  |-- sqft_basement: integer (nullable = true)
#  |-- yr_built: integer (nullable = true)
#  |-- yr_renovated: integer (nullable = true)
#  |-- zipcode: integer (nullable = true)
#  |-- lat: double (nullable = true)
#  |-- long: double (nullable = true)
#  |-- sqft_living15: integer (nullable = true)
#  |-- sqft_lot15: integer (nullable = true)

# %%
df.describe().show()
# Out:
# +-------+--------------------+------------------+-----------------+------------------+------------------+------------------+------------------+--------------------+-------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+-------------------+-------------------+-----------------+------------------+
# |summary|                  id|             price|         bedrooms|         bathrooms|       sqft_living|          sqft_lot|            floors|          waterfront|               view|         condition|             grade|        sqft_above|     sqft_basement|          yr_built|      yr_renovated|           zipcode|                lat|               long|    sqft_living15|        sqft_lot15|
# +-------+--------------------+------------------+-----------------+------------------+------------------+------------------+------------------+--------------------+-------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+-------------------+-------------------+-----------------+------------------+
# |  count|                5521|             21613|            21613|             21613|             21613|             21613|             21613|               21613|              21613|             21613|             21613|             21613|             21613|             21613|             21613|             21613|              21613|              21613|            21613|             21613|
# |   mean|1.1699928617621808E9| 540088.1417665294| 3.37084162309721|2.1147573219821405|2079.8997362698374|15106.967565816869|1.4943089807060566|0.007541757275713691|0.23430342849211122|3.4094295100171195| 7.656873178179799|1788.3906907879516| 291.5090454818859|1971.0051357978994| 84.40225790033776| 98077.93980474715|  47.56005251931704|-122.21389640494083|1986.552491556008|12768.455651691113|
# | stddev| 6.100576160065911E8|367127.19648270035|0.930061831147451| 0.770163157217741| 918.4408970468096| 41420.51151513551|0.5399888951423489| 0.08651719772788748| 0.7663175692736114|0.6507430463662044|1.1754587569743344| 828.0909776519175|442.57504267746685|29.373410802386243|401.67924001917504|53.505026257472466|0.13856371024192368|0.14082834238139288|685.3913042527788|27304.179631338524|
# |    min|             1000102|           75000.0|                0|               0.0|               290|               520|               1.0|                   0|                  0|                 1|                 1|               290|                 0|              1900|                 0|             98001|            47.1559|           -122.519|              399|               651|
# |    max|          2147300050|         7700000.0|               33|               8.0|             13540|           1651359|               3.5|                   1|                  4|                 5|                13|              9410|              4820|              2015|              2015|             98199|            47.7776|           -121.315|             6210|            871200|
# +-------+--------------------+------------------+-----------------+------------------+------------------+------------------+------------------+--------------------+-------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+-------------------+-------------------+-----------------+------------------+

# %%
from pyspark.sql.functions import col, when, log1p

def winsorize_and_log_transform(df, winsorize_features, log_features, lower_percentile=0.01, upper_percentile=0.99):
    """
    Perform winsorization and log transformation on a PySpark DataFrame.

    Args:
        df (DataFrame): The input PySpark DataFrame.
        winsorize_features (list): List of numeric columns to apply winsorization.
        log_features (list): List of numeric columns to apply log transformation.
        lower_percentile (float): Lower bound percentile (default: 0.01).
        upper_percentile (float): Upper bound percentile (default: 0.99).

    Returns:
        DataFrame: Transformed DataFrame with winsorized and log-transformed values.
    """
    bounds = {}  # Store lower and upper bounds for winsorization

    # Compute percentile values for each column
    for feature in winsorize_features:
        lower_bound, upper_bound = df.approxQuantile(feature, [lower_percentile, upper_percentile], 0.0)
        bounds[feature] = (lower_bound, upper_bound)

    # Apply winsorization
    for feature, (lower_bound, upper_bound) in bounds.items():
        df = df.withColumn(
            feature,
            when(col(feature) < lower_bound, lower_bound)
            .when(col(feature) > upper_bound, upper_bound)
            .otherwise(col(feature))
        )

    # Apply log transformation
    for feature in log_features:
        df = df.withColumn(feature, log1p(col(feature)))  # log(x + 1) to avoid log(0) issues

    return df

# %%
winsorize_features = ['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'sqft_above', 'sqft_basement']
log_features = ['price', 'sqft_living', 'sqft_lot', 'sqft_above', 'sqft_basement', 'sqft_living15', 'sqft_lot15']

df = winsorize_and_log_transform(df, winsorize_features, log_features)

# %%
df.describe().show()
# Out:
# +-------+--------------------+------------------+------------------+------------------+-----------------+------------------+------------------+--------------------+-------------------+------------------+------------------+-------------------+------------------+------------------+------------------+------------------+-------------------+-------------------+------------------+------------------+
# |summary|                  id|             price|          bedrooms|         bathrooms|      sqft_living|          sqft_lot|            floors|          waterfront|               view|         condition|             grade|         sqft_above|     sqft_basement|          yr_built|      yr_renovated|           zipcode|                lat|               long|     sqft_living15|        sqft_lot15|
# +-------+--------------------+------------------+------------------+------------------+-----------------+------------------+------------------+--------------------+-------------------+------------------+------------------+-------------------+------------------+------------------+------------------+------------------+-------------------+-------------------+------------------+------------------+
# |  count|                5521|             21613|             21613|             21613|            21613|             21613|             21613|               21613|              21613|             21613|             21613|              21613|             21613|             21613|             21613|             21613|              21613|              21613|             21613|             21613|
# |   mean|1.1699928617621808E9|13.047819371572741|3.3754221996020912| 2.110500624624069|7.550548464156443| 8.988424545145607|1.4943089807060566|0.007541757275713691|0.23430342849211122|3.4094295100171195| 7.656873178179799|   7.39551689974515| 2.527610029984447|1971.0051357978994| 84.40225790033776| 98077.93980474715|  47.56005251931704|-122.21389640494083| 7.540000421015086| 8.961155190756372|
# | stddev| 6.100576160065911E8|0.5266833372794075|0.8662611063041205|0.7468248039319407|0.416690071730507|0.8853055848979617|0.5399888951423489| 0.08651719772788748| 0.7663175692736114|0.6507430463662044|1.1754587569743344|0.42012131658732527|3.1679419543388945|29.373410802386243|401.67924001917504|53.505026257472466|0.13856371024192368|0.14082834238139288|0.3273377863688272|0.8129264732068328|
# |    min|             1000102|11.225256725762893|               2.0|               1.0|6.580639137284949| 6.921658184151129|               1.0|                   0|                  0|                 1|                 1|   6.55250788703459|               0.0|              1900|                 0|             98001|            47.1559|           -122.519| 5.991464547107982| 6.480044561926653|
# |    max|          2147300050|15.856731016694035|               6.0|              4.25|8.513385953073284|12.269089697320034|               3.5|                   1|                  4|                 5|                13|  8.382747094863314| 7.415175109613295|              2015|              2015|             98199|            47.7776|           -121.315| 8.734077192559303|13.677627998442286|
# +-------+--------------------+------------------+------------------+------------------+-----------------+------------------+------------------+--------------------+-------------------+------------------+------------------+-------------------+------------------+------------------+------------------+------------------+-------------------+-------------------+------------------+------------------+

# %%
df = df.drop('lat', 'long', 'id', 'date')

# %%
df.show()
# Out:
# +------------------+--------+---------+------------------+------------------+------+----------+----+---------+-----+------------------+-----------------+--------+------------+-------+-----------------+------------------+
# |             price|bedrooms|bathrooms|       sqft_living|          sqft_lot|floors|waterfront|view|condition|grade|        sqft_above|    sqft_basement|yr_built|yr_renovated|zipcode|    sqft_living15|        sqft_lot15|
# +------------------+--------+---------+------------------+------------------+------+----------+----+---------+-----+------------------+-----------------+--------+------------+-------+-----------------+------------------+
# |12.309986615445005|     3.0|      1.0| 7.074116816197362| 8.639587799629844|   1.0|         0|   0|        3|    7| 7.074116816197362|              0.0|    1955|           0|  98178|7.201170883281678| 8.639587799629844|
# |13.195615697878253|     3.0|     2.25| 7.852050207265889| 8.887790764195326|   2.0|         0|   0|        3|    7| 7.682943169878292|5.993961427306569|    1951|        1991|  98125| 7.43307534889858| 8.941152882160566|
# |12.100717685412471|     2.0|      1.0| 6.647688373563329| 9.210440366976517|   1.0|         0|   0|        3|    6| 6.647688373563329|              0.0|    1933|           0|  98028|7.908754738783246| 8.995040974685022|
# |13.311331132544721|     4.0|      3.0| 7.581209826196346| 8.517393171418904|   1.0|         0|   0|        5|    7| 6.957497370876951|6.814542897259958|    1965|           0|  98136|7.215975002651466| 8.517393171418904|
# |  13.1421679654829|     3.0|      2.0| 7.427144133408616| 8.997270906233448|   1.0|         0|   0|        3|    8| 7.427144133408616|              0.0|    1987|           0|  98074|7.496097345175956|  8.92319149068606|
# |14.018452218287162|     4.0|     4.25| 8.513385953073284|11.532051392768706|   1.0|         0|   0|        3|   11| 8.266421472984554|7.333676395657684|    2001|           0|  98053| 8.46821300919452|11.532051392768706|
# |12.458778882573533|     3.0|     2.25| 7.447751280047908| 8.827614750837508|   2.0|         0|   0|        3|    7| 7.447751280047908|              0.0|    1995|           0|  98003|7.713784616598755| 8.827614750837508|
# |12.583998677043747|     3.0|      1.5| 6.966967138613983| 9.181117513299279|   1.0|         0|   0|        3|    7| 6.966967138613983|              0.0|    1963|           0|  98198|7.409136443920128| 9.181117513299279|
# |12.343662665771719|     3.0|      1.0| 7.484930283289661| 8.918784137975802|   1.0|         0|   0|        3|    7| 6.957497370876951|6.594413459749778|    1960|           0|  98146|7.484930283289661| 9.001346243766392|
# |12.685410698175232|     3.0|      2.5| 7.544861068658458| 8.788898309344878|   2.0|         0|   0|        3|    7| 7.544861068658458|              0.0|    2003|           0|  98038|7.779466967458324| 8.932080438103307|
# |13.403777346275337|     3.0|      2.5| 8.177796683277778| 9.189831495344642|   1.0|         0|   0|        3|    8| 7.528869256642251|7.415175109613295|    1965|           0|  98007|7.701200180857446| 9.096723645189215|
# |13.056225711649638|     2.0|      1.0| 7.057036981697891| 8.699681400989514|   1.0|         0|   0|        4|    7|6.7580945044277305|5.707110264748875|    1942|           0|  98115|7.193685818395112| 8.699681400989514|
# |12.644330802262578|     3.0|      1.0| 7.266128779556451| 9.898575508175107|   1.5|         0|   0|        4|    7| 7.266128779556451|              0.0|    1927|           0|  98028|7.484930283289661| 9.449199779730396|
# |12.899222326086994|     3.0|     1.75| 7.223295679562314| 9.177920480720072|   1.0|         0|   0|        4|    7| 7.223295679562314|              0.0|    1977|           0|  98074|7.223295679562314| 9.231024963169016|
# |13.180634172318978|     5.0|      2.0| 7.501634457883413| 8.486940148245216|   1.5|         0|   0|        3|    7| 7.501634457883413|              0.0|    1900|           0|  98107|7.215975002651466| 8.486940148245216|
# |13.384729180332174|     4.0|      3.0| 7.989899374942939| 8.517393171418904|   2.0|         0|   3|        3|    9| 7.591357046698551|6.878326468291325|    1979|           0|  98126|7.669028288589683| 8.294299608857235|
# |12.886643575525625|     3.0|      2.0| 7.544861068658458| 9.549736900114642|   2.0|         0|   0|        3|    7| 7.544861068658458|              0.0|    1994|           0|  98019|7.544861068658458| 9.548168831368535|
# |13.091906231773164|     4.0|      1.0|7.3783837129967145| 8.366602832783736|   1.5|         0|   0|        4|    7|7.3783837129967145|              0.0|    1916|           0|  98103|7.384610383176974| 8.366602832783736|
# |12.149507585033072|     2.0|      1.0|7.0909098220799835|  9.19532825185568|   1.0|         0|   0|        4|    7|7.0909098220799835|              0.0|    1921|           0|  98002|6.966967138613983|    8.536211197252|
# |12.345838935721968|     3.0|      1.0|7.1316985104669115| 9.187583384853566|   1.0|         0|   0|        4|    7|7.1316985104669115|              0.0|    1969|           0|  98003|7.155396301896734| 9.088285725968877|
# +------------------+--------+---------+------------------+------------------+------+----------+----+---------+-----+------------------+-----------------+--------+------------+-------+-----------------+------------------+
# only showing top 20 rows

# %%
train_data, test_data = df.randomSplit([0.8, 0.2], seed=123)

# %%
test_data.show()
# Out:
# +------------------+--------+---------+------------------+-----------------+------+----------+----+---------+-----+------------------+-----------------+--------+------------+-------+------------------+-----------------+
# |             price|bedrooms|bathrooms|       sqft_living|         sqft_lot|floors|waterfront|view|condition|grade|        sqft_above|    sqft_basement|yr_built|yr_renovated|zipcode|     sqft_living15|       sqft_lot15|
# +------------------+--------+---------+------------------+-----------------+------+----------+----+---------+-----+------------------+-----------------+--------+------------+-------+------------------+-----------------+
# |11.289794413577894|     2.0|      1.0| 6.580639137284949|8.527341522468053|   1.0|         0|   0|        2|    4|  6.55250788703459|              0.0|    1912|           0|  98014|7.0909098220799835|8.922791623969637|
# |11.326607934898927|     2.0|      1.0| 6.803505257608338|9.057305735807121|   1.0|         0|   0|        3|    5| 6.803505257608338|              0.0|    1918|           0|  98168| 7.630946580890459|8.784774592161016|
# |11.407020356604264|     2.0|      1.0| 6.580639137284949|8.314097335405807|   1.0|         0|   0|        3|    5|  6.55250788703459|              0.0|    1942|           0|  98146| 6.792344427470809|8.537191877922927|
# |11.407576060361786|     2.0|      1.0| 6.580639137284949|8.323851131338817|   1.0|         0|   0|        3|    4|  6.55250788703459|              0.0|    1947|           0|  98106|6.8885724595653635|8.323851131338817|
# |11.429554725537322|     2.0|      1.0| 6.634633357861686|8.612685172875459|   1.5|         0|   0|        3|    5| 6.634633357861686|              0.0|    1947|           0|  98168| 6.947937068614969|8.615408238913192|
# |11.477308649967686|     3.0|      1.0| 6.734591659972948| 9.40029935589935|   1.0|         0|   0|        3|    6| 6.734591659972948|              0.0|    1959|           0|  98023| 6.734591659972948|9.140454244512016|
# | 11.51293546492023|     2.0|      1.0| 6.836259277277067|8.939056445334039|   1.0|         0|   0|        2|    6| 6.836259277277067|              0.0|    1942|           0|  98166| 7.170888478512505|8.941414628006845|
# | 11.51293546492023|     4.0|      1.0|  7.02197642307216|7.895808377083183|   1.0|         0|   0|        3|    5|6.7580945044277305|5.564520407322694|    1939|           0|  98055|  7.02197642307216| 8.48446336679332|
# |11.561725152903833|     3.0|      1.0| 6.734591659972948|9.036106025364846|   1.0|         0|   0|        3|    6| 6.734591659972948|              0.0|    1959|           0|  98023| 6.734591659972948|9.153875834995056|
# |11.561725152903833|     3.0|      1.0|  6.78105762593618|9.804219550877459|   1.0|         0|   0|        4|    6|  6.78105762593618|              0.0|    1970|           0|  98042| 6.846943139585379|9.323133199451306|
# |11.566475710526321|     2.0|      1.0| 6.836259277277067|8.954286157204713|   1.0|         0|   0|        1|    5| 6.836259277277067|              0.0|    1932|           0|  98148| 7.390798521735676|9.057771773331575|
# |11.580593459194764|     3.0|      1.5| 6.814542897259958| 8.54110501146255|   1.0|         0|   0|        3|    6| 6.814542897259958|              0.0|    1973|           0|  98106|7.2520539518528135|8.543445562560303|
# |11.603688960617083|     2.0|      1.0|  6.68586094706836|9.271059107010888|   1.0|         0|   0|        3|    6|  6.68586094706836|              0.0|    1942|           0|  98168| 7.030857476116121|9.271059107010888|
# |11.608244735642321|     2.0|      1.0|6.7226297948554485|8.934718614016768|   1.0|         0|   0|        2|    6|6.7226297948554485|              0.0|    1943|           0|  98166|6.8885724595653635|8.934718614016768|
# |11.652696102959753|     2.0|      1.0| 6.673297967767654|8.889170455363413|   1.0|         0|   0|        3|    5| 6.673297967767654|              0.0|    1930|           0|  98146| 7.139660335964919|9.347577390281268|
# |11.678448377988165|     2.0|      1.0| 6.580639137284949|8.981932990986873|   1.0|         0|   0|        4|    6|  6.55250788703459|              0.0|    1978|           0|  98038|7.3783837129967145|8.981932990986873|
# |11.728044909070785|     3.0|      1.0| 6.985641817639208|8.740496729931813|   1.0|         0|   0|        2|    5| 6.985641817639208|              0.0|    1950|           0|  98168| 6.976348070447749|8.740496729931813|
# |11.736077016252437|     2.0|      1.0| 6.580639137284949|8.914760527397261|   1.0|         0|   0|        1|    5|  6.55250788703459|              0.0|    1928|           0|  98106| 7.208600337960199|8.914760527397261|
# |11.744045122410057|     2.0|      1.0| 6.580639137284949| 8.38958706681109|   1.0|         0|   0|        3|    5|  6.55250788703459|              0.0|    1922|           0|  98055| 6.994849985833071|8.503297086224126|
# |11.775297421715827|     2.0|      1.0| 6.580639137284949|7.313886831633462|   1.0|         0|   0|        4|    4|  6.55250788703459|              0.0|    1900|           0|  98027| 7.030857476116121|8.699681400989514|
# +------------------+--------+---------+------------------+-----------------+------+----------+----+---------+-----+------------------+-----------------+--------+------------+-------+------------------+-----------------+
# only showing top 20 rows

# %%
train_data.show()
# Out:
# +------------------+--------+---------+------------------+------------------+------+----------+----+---------+-----+------------------+-------------+--------+------------+-------+------------------+------------------+
# |             price|bedrooms|bathrooms|       sqft_living|          sqft_lot|floors|waterfront|view|condition|grade|        sqft_above|sqft_basement|yr_built|yr_renovated|zipcode|     sqft_living15|        sqft_lot15|
# +------------------+--------+---------+------------------+------------------+------+----------+----+---------+-----+------------------+-------------+--------+------------+-------+------------------+------------------+
# |11.225256725762893|     2.0|      1.0| 6.580639137284949|10.677707679122552|   1.0|         0|   0|        3|    3|  6.55250788703459|          0.0|    1966|           0|  98022| 7.057036981697891|10.666230755983976|
# |11.264476926102367|     2.0|      1.0| 6.660575149839686|  9.70167731915831|   1.0|         0|   0|        1|    5| 6.660575149839686|          0.0|    1942|           0|  98168| 7.438971592395862| 9.248406572782638|
# |11.302216779257382|     2.0|      1.0| 6.594413459749778| 9.207937487359873|   1.0|         0|   0|        1|    5| 6.594413459749778|          0.0|    1943|           0|  98168|6.7580945044277305| 9.105090961257085|
# |11.314486721293981|     3.0|      1.0|6.7580945044277305| 9.252153874789594|   1.0|         0|   0|        3|    6|6.7580945044277305|          0.0|    1954|           0|  98146| 7.039660349862076| 9.328212292571072|
# |11.320565693461432|     2.0|      1.0| 6.580639137284949| 10.01391023378622|   1.0|         0|   0|        2|    5|  6.55250788703459|          0.0|    1951|           0|  98168| 7.360739903058278| 9.265869681768663|
# |11.338583982516495|     2.0|      1.0| 6.580639137284949| 9.910016194498828|   1.0|         0|   0|        3|    6|  6.55250788703459|          0.0|    1949|           0|  98168| 7.307202314764738| 9.832582139020353|
# |11.350418300109132|     2.0|      1.0|6.7226297948554485| 9.105090961257085|   1.0|         0|   0|        3|    6|6.7226297948554485|          0.0|    1939|           0|  98032| 7.057036981697891| 8.946505025998682|
# |11.350418300109132|     2.0|      1.0| 6.814542897259958| 9.185432736269998|   1.0|         0|   0|        3|    5| 6.814542897259958|          0.0|    1947|           0|  98032| 7.057036981697891| 8.910045761473558|
# |11.367911253546788|     3.0|      1.0| 6.734591659972948|  9.15704507491796|   1.0|         0|   0|        3|    6| 6.734591659972948|          0.0|    1960|           0|  98023| 6.734591659972948| 9.150696519048667|
# | 11.39640288460621|     3.0|      1.0| 6.803505257608338|  8.46611040118692|   1.0|         0|   0|        4|    6| 6.803505257608338|          0.0|    1969|           0|  98023| 6.803505257608338| 8.133000218583613|
# |11.407576060361786|     2.0|      1.0| 6.580639137284949| 8.922791623969637|   1.0|         0|   0|        3|    5|  6.55250788703459|          0.0|    1943|           0|  98178| 7.438971592395862| 9.328212292571072|
# |11.407576060361786|     2.0|      1.0| 6.660575149839686| 8.294299608857235|   1.0|         0|   0|        3|    5| 6.660575149839686|          0.0|    1905|           0|  98108| 7.048386408721883| 8.294299608857235|
# |11.407576060361786|     2.0|      1.0| 6.673297967767654| 7.878912912297132|   1.0|         0|   0|        3|    7| 6.673297967767654|          0.0|    1973|           0|  98034|   7.1785454837637| 7.632885505395133|
# |11.407576060361786|     3.0|      1.0|6.8885724595653635| 7.820439515262181|   2.0|         0|   0|        4|    6|6.8885724595653635|          0.0|    1969|           0|  98092|6.8885724595653635| 8.056743774975313|
# |11.461642696843066|     2.0|      1.0| 6.634633357861686| 8.656433258507741|   1.0|         0|   0|        4|    5| 6.634633357861686|          0.0|    1915|           0|  98002| 6.878326468291325|  8.80941494391005|
# |11.461642696843066|     2.0|      1.0|  6.68586094706836| 9.053803514155955|   1.0|         0|   0|        3|    7|  6.68586094706836|          0.0|    1947|           0|  98198| 7.307202314764738| 9.053803514155955|
# |11.461642696843066|     2.0|      1.0|6.8679744089702925| 8.853808274977197|   1.0|         0|   0|        3|    4|6.8679744089702925|          0.0|    1918|           0|  98198| 7.523481312573497| 9.002208578282412|
# |11.461642696843066|     2.0|      1.0| 6.976348070447749| 9.925787060030896|   1.0|         0|   0|        2|    6| 6.976348070447749|          0.0|    1948|           0|  98058| 7.215975002651466| 9.653871680890804|
# |11.502885230075814|     2.0|      1.0|6.8679744089702925| 9.016391478941248|   1.0|         0|   0|        2|    6|6.8679744089702925|          0.0|    1948|           0|  98058| 7.139660335964919| 9.016391478941248|
# | 11.51293546492023|     2.0|      1.0| 6.580639137284949| 8.564267598802166|   1.0|         0|   0|        4|    4|  6.55250788703459|          0.0|    1912|           0|  98032|6.7464121285733745| 8.533263371593732|
# +------------------+--------+---------+------------------+------------------+------+----------+----+---------+-----+------------------+-------------+--------+------------+-------+------------------+------------------+
# only showing top 20 rows

# %%
from pyspark.ml.feature import StringIndexer, OneHotEncoder, VectorAssembler, StandardScaler
from pyspark.ml import Pipeline

categorical_features_ordinal = ['bedrooms', 'floors', 'view', 'condition', 'grade']
numerical_features = ['bathrooms', 'sqft_living', 'sqft_lot', 'sqft_above', 'sqft_basement', 'sqft_living15', 'sqft_lot15', 'yr_built']

# Ordinal Encoding using StringIndexer
ordinal_indexers = [StringIndexer(inputCol=col, outputCol=f"{col}_indexed", handleInvalid="keep") for col in categorical_features_ordinal]

# StandardScaler for numerical features
vector_assembler = VectorAssembler(inputCols=numerical_features, outputCol="num_features_vector")
scaler = StandardScaler(inputCol="num_features_vector", outputCol="num_features_scaled", withMean=True, withStd=True)

# One-Hot Encoding for Zipcode
zipcode_indexer = StringIndexer(inputCol="zipcode", outputCol="zipcode_indexed", handleInvalid="keep")
zipcode_encoder = OneHotEncoder(inputCol="zipcode_indexed", outputCol="zipcode_ohe")

# Assemble final features
feature_assembler = VectorAssembler(
    inputCols=[f"{col}_indexed" for col in categorical_features_ordinal] + ["num_features_scaled", "zipcode_ohe"],
    outputCol="final_features"
)

# Define PySpark Pipeline
preprocessor = Pipeline(stages=ordinal_indexers + [vector_assembler, scaler, zipcode_indexer, zipcode_encoder, feature_assembler])

# %%
# **Fit only on training data**
fitted_pipeline = preprocessor.fit(train_data)

# Transform both training and test sets
train_df_transformed = fitted_pipeline.transform(train_data)
test_df_transformed = fitted_pipeline.transform(test_data)

# %%
train_df_transformed = train_df_transformed.select('price', 'final_features')
train_df_transformed.show()
# Out:
# +------------------+--------------------+
# |             price|      final_features|
# +------------------+--------------------+
# |11.225256725762893|(83,[0,4,5,6,7,8,...|
# |11.264476926102367|(83,[0,3,4,5,6,7,...|
# |11.302216779257382|(83,[0,3,4,5,6,7,...|
# |11.314486721293981|(83,[4,5,6,7,8,9,...|
# |11.320565693461432|(83,[0,3,4,5,6,7,...|
# |11.338583982516495|(83,[0,4,5,6,7,8,...|
# |11.350418300109132|(83,[0,4,5,6,7,8,...|
# |11.350418300109132|(83,[0,4,5,6,7,8,...|
# |11.367911253546788|(83,[4,5,6,7,8,9,...|
# | 11.39640288460621|(83,[3,4,5,6,7,8,...|
# |11.407576060361786|(83,[0,4,5,6,7,8,...|
# |11.407576060361786|(83,[0,4,5,6,7,8,...|
# |11.407576060361786|(83,[0,5,6,7,8,9,...|
# |11.407576060361786|(83,[1,3,4,5,6,7,...|
# |11.461642696843066|(83,[0,3,4,5,6,7,...|
# |11.461642696843066|(83,[0,5,6,7,8,9,...|
# |11.461642696843066|(83,[0,4,5,6,7,8,...|
# |11.461642696843066|(83,[0,3,4,5,6,7,...|
# |11.502885230075814|(83,[0,3,4,5,6,7,...|
# | 11.51293546492023|(83,[0,3,4,5,6,7,...|
# +------------------+--------------------+
# only showing top 20 rows

# %%
test_df_transformed = test_df_transformed.select('price', 'final_features')
test_df_transformed.show()
# Out:
# +------------------+--------------------+
# |             price|      final_features|
# +------------------+--------------------+
# |11.289794413577894|(83,[0,3,4,5,6,7,...|
# |11.326607934898927|(83,[0,4,5,6,7,8,...|
# |11.407020356604264|(83,[0,4,5,6,7,8,...|
# |11.407576060361786|(83,[0,4,5,6,7,8,...|
# |11.429554725537322|(83,[0,1,4,5,6,7,...|
# |11.477308649967686|(83,[4,5,6,7,8,9,...|
# | 11.51293546492023|(83,[0,3,4,5,6,7,...|
# | 11.51293546492023|(83,[0,4,5,6,7,8,...|
# |11.561725152903833|(83,[4,5,6,7,8,9,...|
# |11.561725152903833|(83,[3,4,5,6,7,8,...|
# |11.566475710526321|(83,[0,3,4,5,6,7,...|
# |11.580593459194764|(83,[4,5,6,7,8,9,...|
# |11.603688960617083|(83,[0,4,5,6,7,8,...|
# |11.608244735642321|(83,[0,3,4,5,6,7,...|
# |11.652696102959753|(83,[0,4,5,6,7,8,...|
# |11.678448377988165|(83,[0,3,4,5,6,7,...|
# |11.728044909070785|(83,[3,4,5,6,7,8,...|
# |11.736077016252437|(83,[0,3,4,5,6,7,...|
# |11.744045122410057|(83,[0,4,5,6,7,8,...|
# |11.775297421715827|(83,[0,3,4,5,6,7,...|
# +------------------+--------------------+
# only showing top 20 rows

# %%
from xgboost.spark import SparkXGBRegressor
from pyspark.ml.evaluation import RegressionEvaluator


xgb = SparkXGBRegressor(features_col="final_features", label_col="price")

# %%
model = xgb.fit(train_df_transformed)
# Out:
# INFO:XGBoost-PySpark:Running xgboost-2.1.4 on 1 workers with
# 	booster params: {'objective': 'reg:squarederror', 'device': 'cpu', 'nthread': 1}
# 	train_call_kwargs_params: {'verbose_eval': True, 'num_boost_round': 100}
# 	dmatrix_kwargs: {'nthread': 1, 'missing': nan}
# INFO:XGBoost-PySpark:Finished xgboost training!

# %%
predictions = model.transform(test_df_transformed)

# %%
predictions.show(5)
# Out:
# +------------------+--------------------+------------------+
# |             price|      final_features|        prediction|
# +------------------+--------------------+------------------+
# |11.289794413577894|(83,[0,3,4,5,6,7,...|12.174543380737305|
# |11.326607934898927|(83,[0,4,5,6,7,8,...|12.347636222839355|
# |11.407020356604264|(83,[0,4,5,6,7,8,...| 12.13211727142334|
# |11.407576060361786|(83,[0,4,5,6,7,8,...|12.207798957824707|
# |11.429554725537322|(83,[0,1,4,5,6,7,...|12.091056823730469|
# +------------------+--------------------+------------------+
# only showing top 5 rows

# %%
from pyspark.sql.functions import expm1

## IMPORTANT: Need to convert predictions back to original scale
predictions = predictions.withColumn("price_predicted", expm1(col("prediction")))
predictions = predictions.withColumn("original_price", expm1(col("price")))

# %%
predictions.show(5)
# Out:
# +------------------+--------------------+------------------+------------------+-----------------+
# |             price|      final_features|        prediction|   price_predicted|   original_price|
# +------------------+--------------------+------------------+------------------+-----------------+
# |11.289794413577894|(83,[0,3,4,5,6,7,...|12.174543380737305| 193791.5199098077|          80000.0|
# |11.326607934898927|(83,[0,4,5,6,7,8,...|12.347636222839355| 230413.7495362661|          83000.0|
# |11.407020356604264|(83,[0,4,5,6,7,8,...| 12.13211727142334|185741.62751396155|89949.99999999993|
# |11.407576060361786|(83,[0,4,5,6,7,8,...|12.207798957824707|200344.56064588373|90000.00000000001|
# |11.429554725537322|(83,[0,1,4,5,6,7,...|12.091056823730469|178269.40820036113|92000.00000000007|
# +------------------+--------------------+------------------+------------------+-----------------+
# only showing top 5 rows

# %%
from pyspark.ml.evaluation import RegressionEvaluator

# Evaluate RMSE using original numbers for interpretability
rmse_evaluator = RegressionEvaluator(labelCol="original_price", predictionCol="price_predicted", metricName="rmse")
rmse = rmse_evaluator.evaluate(predictions)

# Evaluate r squared
r2_evaluator = RegressionEvaluator(labelCol="price", predictionCol="prediction", metricName="r2")
r2 = r2_evaluator.evaluate(predictions)

print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"R² Score: {r2}")
# Out:
# Root Mean Squared Error (RMSE): 136293.50181992393
# R² Score: 0.8753232438754306

# %%
df_pandas = predictions.toPandas()

# %%
predictions = model.transform(test_df_transformed)

# %%
predictions.show(5)
# Out:
# +------------------+--------------------+------------------+
# |             price|      final_features|        prediction|
# +------------------+--------------------+------------------+
# |11.289794413577894|(83,[0,3,4,5,6,7,...|12.174543380737305|
# |11.326607934898927|(83,[0,4,5,6,7,8,...|12.347636222839355|
# |11.407020356604264|(83,[0,4,5,6,7,8,...| 12.13211727142334|
# |11.407576060361786|(83,[0,4,5,6,7,8,...|12.207798957824707|
# |11.429554725537322|(83,[0,1,4,5,6,7,...|12.091056823730469|
# +------------------+--------------------+------------------+
# only showing top 5 rows

# %%
from pyspark.sql.functions import expm1

## IMPORTANT: Need to convert predictions back to original scale
predictions = predictions.withColumn("price_predicted", expm1(col("prediction")))
predictions = predictions.withColumn("original_price", expm1(col("price")))

# %%
predictions.show(5)
# Out:
# +------------------+--------------------+------------------+------------------+-----------------+
# |             price|      final_features|        prediction|   price_predicted|   original_price|
# +------------------+--------------------+------------------+------------------+-----------------+
# |11.289794413577894|(83,[0,3,4,5,6,7,...|12.174543380737305| 193791.5199098077|          80000.0|
# |11.326607934898927|(83,[0,4,5,6,7,8,...|12.347636222839355| 230413.7495362661|          83000.0|
# |11.407020356604264|(83,[0,4,5,6,7,8,...| 12.13211727142334|185741.62751396155|89949.99999999993|
# |11.407576060361786|(83,[0,4,5,6,7,8,...|12.207798957824707|200344.56064588373|90000.00000000001|
# |11.429554725537322|(83,[0,1,4,5,6,7,...|12.091056823730469|178269.40820036113|92000.00000000007|
# +------------------+--------------------+------------------+------------------+-----------------+
# only showing top 5 rows

# %%
predictions.describe().show()
# Out:
# +-------+------------------+-------------------+------------------+------------------+
# |summary|             price|         prediction|   price_predicted|    original_price|
# +-------+------------------+-------------------+------------------+------------------+
# |  count|              4396|               4396|              4396|              4396|
# |   mean|13.049077875901652| 13.048597049669747| 528680.1623772489| 539995.0568698817|
# | stddev|0.5263320640897787|0.48858871625459294|  319651.215915996|361138.76671988243|
# |    min|11.289794413577894|  11.62883472442627|112288.39755001017|           80000.0|
# |    max|15.744855835388163| 15.567222595214844| 5764462.208540291| 6884999.999999994|
# +-------+------------------+-------------------+------------------+------------------+

# %%
df_pandas = predictions.toPandas()

# %%
df_pandas.head()
# Out:
#        price                                     final_features  prediction  \
# 0  11.289794  (2.0, 0.0, 0.0, 3.0, 8.0, -1.4879493311138423,...   12.174543
# 1  11.326608  (2.0, 0.0, 0.0, 0.0, 6.0, -1.4879493311138423,...   12.347636
# 2  11.407020  (2.0, 0.0, 0.0, 0.0, 6.0, -1.4879493311138423,...   12.132117
# 3  11.407576  (2.0, 0.0, 0.0, 0.0, 8.0, -1.4879493311138423,...   12.207799
# 4  11.429555  (2.0, 2.0, 0.0, 0.0, 6.0, -1.4879493311138423,...   12.091057
#
#    price_predicted  original_price
# 0    193791.519910         80000.0
# 1    230413.749536         83000.0
# 2    185741.627514         89950.0
# 3    200344.560646         90000.0
# 4    178269.408200         92000.0

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x=df_pandas['original_price'], y=df_pandas['price_predicted'], alpha=0.6, edgecolor=None)

plt.plot([min(df_pandas['original_price']), max(df_pandas['original_price'])],
         [min(df_pandas['original_price']), max(df_pandas['original_price'])],
         color='red', linestyle='--', linewidth=2, label="Perfect Prediction")

plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title("Actual vs. Predicted Prices")

plt.ticklabel_format(style='plain', axis='both')

sns.despine()
plt.legend()
plt.show()

# %%
residuals = df_pandas['original_price'] - df_pandas['price_predicted']

plt.figure(figsize=(8, 6))
sns.histplot(residuals, bins=50, kde=True, color="steelblue")

plt.xlabel("Residual (Error)")
plt.ylabel("Frequency")
plt.title("Residual Distribution")

plt.ticklabel_format(style='plain', axis='both')

sns.despine()
plt.show()
